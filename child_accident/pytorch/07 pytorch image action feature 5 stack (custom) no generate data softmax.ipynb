# %%
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import numpy as np
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class data():
    def __init__(self, seq_length, batch_size):
        np.random.seed(100)
        self.seq_length = seq_length
        self.acc_num = 334
        self.no_acc_num = 392
        self.split = 0.95
        self.train_index = 0 
        self.train_batch_size = batch_size
        self.valid_index = 0
        self.valid_batch_size = 10
        self.read_annotation()
        self.shuffle_data()
        
    def shuffle_data(self):
        #img_range = np.arange(0,300-self.seq_length-60,60)
        acc_list = np.arange(1,self.acc_num+1)
        no_acc_list = np.arange(1,self.no_acc_num+1)
        list1 = np.array(np.meshgrid(1,acc_list)).T.reshape(-1,2)
        list2 = np.array(np.meshgrid(0,no_acc_list)).T.reshape(-1,2)
        shuffle_list = np.concatenate([list1, list2], axis=0)
        np.random.shuffle(shuffle_list)
        self.train = shuffle_list[:int(shuffle_list.shape[0]*self.split)]
        self.valid = shuffle_list[int(shuffle_list.shape[0]*self.split):] 
        
    def read_annotation(self):
        annotation_file = '/media/user/Hard_Disk/Dataset/child_accident_2/annotation/accident_frame.txt'
        w = open(annotation_file, "r")
        ann = w.read()
        annotation_data = []
        for i in ann.split("\n"):
            b = i.split(" ")
            if (len(b) > 1):
                annotation_data.append(b[1])
        self.annotation = np.array(annotation_data).astype("int32")
        
    def read_data(self, is_accident, dir_index):
        data = []
        label = []
        img_path = '/media/user/Hard_Disk/Dataset/child_accident_2/image feature/' 
        act_path = '/media/user/Hard_Disk/Dataset/child_accident_2/action feature/' 
        if (is_accident):
            acc_dir = "accident/"
            range_start = self.annotation[dir_index-1] - self.seq_length
            range_end = self.annotation[dir_index-1]
            label.append([0,1])
            
        else:
            acc_dir = "no_accident/"
            range_start = 0
            range_end = self.seq_length
            label.append([1,0])
            
        dir_name = "%04d"%dir_index
        img_npy = []
        act_npy = []
        for j in range(range_start, range_end):
            img_feature = np.load(img_path + acc_dir + dir_name + "/" + str(j) + ".npy")
            img_npy.append(img_feature)
            act_feature = np.load(act_path + acc_dir + dir_name + "/" + str(j) + ".npy")
            act_npy.append(act_feature)
        
            
        return np.array(img_npy), np.array(act_npy) ,np.array(label)
        
    def next_batch(self, mode="train"):
        batch_img = []
        batch_act = []
        batch_y = []
        if (mode == "valid"):
            batch_size = self.valid_batch_size
        elif (mode == "train"):
            batch_size = self.train_batch_size
        for i in range(batch_size):
            if (mode == "train"):
                img, act, label = self.read_data(self.train[self.train_index+i][0], self.train[self.train_index+i][1])
            elif (mode == "valid"):
                img, act, label = self.read_data(self.valid[self.valid_index+i][0], self.valid[self.valid_index+i][1])
            batch_img.append(img)
            batch_act.append(act)
            batch_y.append(label)
        if (mode == "valid"):
            self.valid_index += self.valid_batch_size
        elif (mode == "train"):
            self.train_index += self.train_batch_size
        return np.array(batch_img), np.array(batch_act), np.squeeze(np.array(batch_y))
    
    def has_next(self, mode="train"):
        if (mode == "train"):
            if (self.train_index + self.train_batch_size >= self.train.shape[0]):
                return False
        elif (mode == "valid"):
            if (self.valid_index + self.valid_batch_size >= self.valid.shape[0]):
                return False
        return True
    def display_shape(self):
        print("train shape:",self.train.shape, " valid shape:",self.valid.shape)
        
    def reset_batch(self, mode="train"):
        if (mode == "train"):
            self.train_index = 0
            np.random.shuffle(self.train)
        elif (mode == "valid"):
            self.valid_index = 0

# %%
# Recurrent neural network (many-to-one)
class RNN(nn.Module):
    def __init__(self, img_input_size, act_input_size, hidden_size, embedding_size, embedding_size2, num_layers, num_classes):
        super(RNN, self).__init__()
        
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.img = nn.Sequential(
            nn.Linear(img_input_size, embedding_size),
            nn.Dropout(0.25),
            nn.ReLU(),
            nn.Linear(embedding_size, embedding_size2)
        )
        self.act = nn.Sequential(
            nn.Linear(act_input_size, embedding_size),
            nn.Dropout(0.25),
            nn.ReLU(),
            nn.Linear(embedding_size, embedding_size2)
        )
            
        
        self.img_fc1 = nn.Linear(img_input_size, embedding_size)
        self.act_fc1 = nn.Linear(act_input_size, embedding_size)
        self.img_fc2 = nn.Linear(embedding_size, embedding_size2)
        self.act_fc2 = nn.Linear(embedding_size, embedding_size2)
        self.lstm1 = nn.LSTM(embedding_size2*2, hidden_size, num_layers,dropout=0.25, batch_first=True)
        self.lstm2 = nn.LSTM(embedding_size2*2, hidden_size, num_layers,dropout=0.25, batch_first=True)
        self.lstm3 = nn.LSTM(embedding_size2*2, hidden_size, num_layers,dropout=0.25, batch_first=True)
        self.lstm4 = nn.LSTM(embedding_size2*2, hidden_size, num_layers,dropout=0.25, batch_first=True)
        self.lstm5 = nn.LSTM(embedding_size2*2, hidden_size, num_layers,dropout=0.25, batch_first=True)
        self.st5_state_h = nn.Linear(hidden_size*5, hidden_size)
        self.st5_state_c = nn.Linear(hidden_size*5, hidden_size)
        self.st4_state_h = nn.Linear(hidden_size*4, hidden_size)
        self.st4_state_c = nn.Linear(hidden_size*4, hidden_size)
        self.st3_state_h = nn.Linear(hidden_size*3, hidden_size)
        self.st3_state_c = nn.Linear(hidden_size*3, hidden_size)
        self.st2_state_h = nn.Linear(hidden_size*2, hidden_size)
        self.st2_state_c = nn.Linear(hidden_size*2, hidden_size)
        self.fc2 = nn.Linear(hidden_size, num_classes)
    
    def forward(self, x, y):
        # Set initial hidden and cell states 
        x1 = self.img_fc1(x)
        x1 = self.img_fc2(x1)
        x2 = self.act_fc1(y)
        x2 = self.act_fc2(x2)
#         x1 = self.img(x)
#         x = self.act(y)
        x = torch.cat((x1, x2), 2)
#         print(x.shape)
        
        st1_h = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device) 
        st1_c = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        
        st2_h = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device) 
        st2_c = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        
        st3_h = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device) 
        st3_c = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        
        st4_h = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device) 
        st4_c = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        
        st5_h = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device) 
        st5_c = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        
        for i in range(x.size(1)):
        # Forward propagate LSTM
            stack1_out, (st1_h, st1_c) = self.lstm1(x[:,i].unsqueeze(1), (st1_h, st1_c))  # out: tensor of shape (batch_size, seq_length, hidden_size)
            stack2_out, (st2_h, st2_c) = self.lstm2(x[:,int(i/10)].unsqueeze(1), (st2_h, st2_c))
            stack3_out, (st3_h, st3_c) = self.lstm3(x[:,int(i/20)].unsqueeze(1), (st3_h, st3_c))
            stack4_out, (st4_h, st4_c) = self.lstm3(x[:,int(i/30)].unsqueeze(1), (st4_h, st4_c))
            stack5_out, (st5_h, st5_c) = self.lstm3(x[:,int(i/40)].unsqueeze(1), (st5_h, st5_c))
            
            st5_h = torch.cat((st1_h, st2_h, st3_h, st4_h, st5_h), 2)
            st5_h = self.st5_state_h(st5_h)
            
            st5_c = torch.cat((st1_c, st2_c, st3_c, st4_c, st5_c), 2)
            st5_c = self.st5_state_c(st5_c)
            
            st4_h = torch.cat((st4_h, st4_h, st4_h, st4_h), 2)
            st4_h = self.st4_state_h(st4_h)
            
            st4_c = torch.cat((st1_c, st2_c, st3_c, st4_c), 2)
            st4_c = self.st4_state_c(st4_c)
            
            st3_h = torch.cat((st1_h, st2_h, st3_h), 2)
            st3_h = self.st3_state_h(st3_h)
            
            st3_c = torch.cat((st1_c, st2_c, st3_c), 2)
            st3_c = self.st3_state_c(st3_c)
            
            
            st2_h = torch.cat((st1_h, st2_h), 2)
            st2_h = self.st2_state_h(st2_h)
            
            st2_c = torch.cat((st1_c, st2_c), 2)
            st2_c = self.st2_state_c(st2_c)
            
            
        
        # Decode the hidden state of the last time step
        
        out = self.fc2(stack5_out[:,-1,:])
        
#         out = self.fc2(out[:, -1, :])
        return out

# %%
model = RNN(img_input_size=20*4096, act_input_size=1024, hidden_size=1024, embedding_size=1024, embedding_size2=512, num_layers=1, num_classes=2).to(device)
# Out:
# /home/user/.local/lib/python3.5/site-packages/torch/nn/modules/rnn.py:38: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.25 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %%
w = torch.from_numpy(np.array([1,1])).type(torch.FloatTensor).to(device)
criterion = nn.CrossEntropyLoss(weight=w)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# %%
sequence_length = 100
num_epochs = 20
train_data = data(seq_length=sequence_length, batch_size=50)
train_data.display_shape()
# Out:
# train shape: (689, 2)  valid shape: (37, 2)

# %%
def evaluation(model):
    i = 0
    acc = 0
    while(train_data.has_next("valid")):
        img, act, labels = train_data.next_batch("valid")
        labels = torch.from_numpy(labels).to(device)
        img = torch.from_numpy(img.reshape(-1, sequence_length, 20*4096)).to(device)
        act = torch.from_numpy(np.squeeze(act)).to(device)
        outputs = model(img, act)
        outputs = F.softmax(outputs)
        predict = torch.max(outputs, 1)[1]
        target = torch.max(labels, 1)[1]
        loss = criterion(outputs, target)
        correct = (predict == target).squeeze()
        acc += torch.nonzero(correct).size(0) / predict.shape[0]
        i += 1
    train_data.reset_batch("valid")
    print("validation accuracy:",acc/i)

# %%
# Loss and optimizer

# Train the model

for epoch in range(101):
    i = 0
    acc = 0
    print("epoch:",epoch)
    while (train_data.has_next("train")):
        img, act, labels = train_data.next_batch("train")
        labels = torch.from_numpy(labels).to(device)
        
        img = torch.from_numpy(img.reshape(-1, sequence_length, 20*4096)).to(device)
        act = torch.from_numpy(np.squeeze(act)).to(device)
        outputs = model(img, act)
        outputs = F.softmax(outputs)
#         print(outputs.shape)
#         outputs, torch.max(labels, 1)[1]
        
        predict = torch.max(outputs, 1)[1]
        target = torch.max(labels, 1)[1]
        loss = criterion(outputs, target)
        
        
        correct = (predict == target).squeeze()
#         print(predict)
#         print(target)
#         print("================")
#         print(correct)
        acc += torch.nonzero(correct).size(0) / predict.shape[0]
        
    
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        i += 1
        if (i+1) % 5 == 0:
            
            print ('Epoch [{}/{}], Step {}, Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, loss.item()))
            print ('train accuracy:',acc/i)
            evaluation(model)
            print("====================================")
    if (epoch % 10 == 0):
        path = "/media/user/Hard_Disk/Dataset/child_accident_2/model/pytorch - 07/model-"+str(epoch)+".ckpt"
        torch.save(model, path)
    train_data.reset_batch("train")
# # Test the model
# with torch.no_grad():
#     correct = 0
#     total = 0
#     for images, labels in test_loader:
#         images = images.reshape(-1, sequence_length, input_size).to(device)
#         labels = labels.to(device)
#         outputs = model(images)
#         _, predicted = torch.max(outputs.data, 1)
#         total += labels.size(0)
#         correct += (predicted == labels).sum().item()

#     print('Test Accuracy of the model on the 10000 test images: {} %'.format(100 * correct / total)) 

# # Save the model checkpoint
# torch.save(model.state_dict(), 'model.ckpt')
# Out:
# epoch: 0
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:17: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Epoch [1/20], Step 5, Loss: 0.6840
# train accuracy: 0.505
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:10: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   # Remove the CWD from sys.path while we load stuff.
# validation accuracy: 0.5333333333333333
# ====================================
# Epoch [1/20], Step 10, Loss: 0.6676
# train accuracy: 0.5422222222222222
# validation accuracy: 0.6666666666666666
# ====================================
# /home/user/.local/lib/python3.5/site-packages/torch/serialization.py:193: UserWarning: Couldn't retrieve source code for container of type RNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# epoch: 1
# Epoch [2/20], Step 5, Loss: 0.6673
# train accuracy: 0.67
# validation accuracy: 0.6999999999999998
# ====================================
# Epoch [2/20], Step 10, Loss: 0.6796
# train accuracy: 0.6599999999999999
# validation accuracy: 0.6999999999999998
# ====================================
# epoch: 2
# Epoch [3/20], Step 5, Loss: 0.6149
# train accuracy: 0.6950000000000001
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [3/20], Step 10, Loss: 0.5652
# train accuracy: 0.6844444444444444
# validation accuracy: 0.7333333333333334
# ====================================
# epoch: 3
# Epoch [4/20], Step 5, Loss: 0.5853
# train accuracy: 0.71
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [4/20], Step 10, Loss: 0.5322
# train accuracy: 0.7377777777777779
# validation accuracy: 0.7666666666666666
# ====================================
# epoch: 4
# Epoch [5/20], Step 5, Loss: 0.5982
# train accuracy: 0.715
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [5/20], Step 10, Loss: 0.5009
# train accuracy: 0.7622222222222221
# validation accuracy: 0.7666666666666666
# ====================================
# epoch: 5
# Epoch [6/20], Step 5, Loss: 0.4965
# train accuracy: 0.7649999999999999
# validation accuracy: 0.7666666666666666
# ====================================
# Epoch [6/20], Step 10, Loss: 0.4652
# train accuracy: 0.7977777777777777
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 6
# Epoch [7/20], Step 5, Loss: 0.4519
# train accuracy: 0.835
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [7/20], Step 10, Loss: 0.4944
# train accuracy: 0.8533333333333333
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 7
# Epoch [8/20], Step 5, Loss: 0.5073
# train accuracy: 0.835
# validation accuracy: 0.7666666666666666
# ====================================
# Epoch [8/20], Step 10, Loss: 0.4159
# train accuracy: 0.8444444444444446
# validation accuracy: 0.7333333333333334
# ====================================
# epoch: 8
# Epoch [9/20], Step 5, Loss: 0.5308
# train accuracy: 0.8700000000000001
# validation accuracy: 0.7666666666666666
# ====================================
# Epoch [9/20], Step 10, Loss: 0.4511
# train accuracy: 0.8755555555555556
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 9
# Epoch [10/20], Step 5, Loss: 0.4595
# train accuracy: 0.88
# validation accuracy: 0.7666666666666667
# ====================================
# Epoch [10/20], Step 10, Loss: 0.4015
# train accuracy: 0.9000000000000001
# validation accuracy: 0.7333333333333334
# ====================================
# epoch: 10
# Epoch [11/20], Step 5, Loss: 0.3975
# train accuracy: 0.945
# validation accuracy: 0.7666666666666666
# ====================================
# Epoch [11/20], Step 10, Loss: 0.3730
# train accuracy: 0.94
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 11
# Epoch [12/20], Step 5, Loss: 0.4037
# train accuracy: 0.955
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [12/20], Step 10, Loss: 0.3413
# train accuracy: 0.9644444444444444
# validation accuracy: 0.7666666666666666
# ====================================
# epoch: 12
# Epoch [13/20], Step 5, Loss: 0.3377
# train accuracy: 0.945
# validation accuracy: 0.7333333333333334
# ====================================
# Epoch [13/20], Step 10, Loss: 0.3374
# train accuracy: 0.9644444444444444
# validation accuracy: 0.7333333333333334
# ====================================
# epoch: 13
# Epoch [14/20], Step 5, Loss: 0.3149
# train accuracy: 0.97
# validation accuracy: 0.7666666666666666
# ====================================
# Epoch [14/20], Step 10, Loss: 0.3152
# train accuracy: 0.9688888888888889
# validation accuracy: 0.7666666666666666
# ====================================
# epoch: 14
# Epoch [15/20], Step 5, Loss: 0.3223
# train accuracy: 0.965
# validation accuracy: 0.7000000000000001
# ====================================
# Epoch [15/20], Step 10, Loss: 0.3557
# train accuracy: 0.9733333333333335
# validation accuracy: 0.7000000000000001
# ====================================
# epoch: 15
# Epoch [16/20], Step 5, Loss: 0.3162
# train accuracy: 0.98
# validation accuracy: 0.7666666666666666
# ====================================
# Epoch [16/20], Step 10, Loss: 0.3339
# train accuracy: 0.9733333333333333
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 16
# Epoch [17/20], Step 5, Loss: 0.4197
# train accuracy: 0.9249999999999999
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [17/20], Step 10, Loss: 0.3432
# train accuracy: 0.9311111111111112
# validation accuracy: 0.7666666666666666
# ====================================
# epoch: 17
# Epoch [18/20], Step 5, Loss: 0.3384
# train accuracy: 0.9349999999999999
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [18/20], Step 10, Loss: 0.3485
# train accuracy: 0.9311111111111112
# validation accuracy: 0.6
# ====================================
# epoch: 18
# Epoch [19/20], Step 5, Loss: 0.3641
# train accuracy: 0.9149999999999999
# validation accuracy: 0.7333333333333334
# ====================================
# Epoch [19/20], Step 10, Loss: 0.3477
# train accuracy: 0.9466666666666667
# validation accuracy: 0.7999999999999999
# ====================================
# epoch: 19
# Epoch [20/20], Step 5, Loss: 0.3240
# train accuracy: 0.965
# validation accuracy: 0.7333333333333334
# ====================================
# Epoch [20/20], Step 10, Loss: 0.3624
# train accuracy: 0.9711111111111109
# validation accuracy: 0.7333333333333334
# ====================================
# epoch: 20
# Epoch [21/20], Step 5, Loss: 0.3252
# train accuracy: 0.97
# validation accuracy: 0.7000000000000001
# ====================================
# Epoch [21/20], Step 10, Loss: 0.3750
# train accuracy: 0.9777777777777776
# validation accuracy: 0.7333333333333334
# ====================================
# epoch: 21
# Epoch [22/20], Step 5, Loss: 0.3142
# train accuracy: 0.98
# validation accuracy: 0.7000000000000001
# ====================================
# Epoch [22/20], Step 10, Loss: 0.3144
# train accuracy: 0.9733333333333333
# validation accuracy: 0.7000000000000001
# ====================================
# epoch: 22
# Epoch [23/20], Step 5, Loss: 0.3737
# train accuracy: 0.96
# validation accuracy: 0.7000000000000001
# ====================================
# Epoch [23/20], Step 10, Loss: 0.3536
# train accuracy: 0.9733333333333335
# validation accuracy: 0.7000000000000001
# ====================================
# epoch: 23
# Epoch [24/20], Step 5, Loss: 0.3335
# train accuracy: 0.985
# validation accuracy: 0.7333333333333334
# ====================================
# Epoch [24/20], Step 10, Loss: 0.3335
# train accuracy: 0.9822222222222222
# validation accuracy: 0.7333333333333334
# ====================================
# epoch: 24
# Epoch [25/20], Step 5, Loss: 0.4319
# train accuracy: 0.945
# validation accuracy: 0.7666666666666666
# ====================================
# Epoch [25/20], Step 10, Loss: 0.3275
# train accuracy: 0.9600000000000001
# validation accuracy: 0.7666666666666666
# ====================================
# epoch: 25
# Epoch [26/20], Step 5, Loss: 0.3824
# train accuracy: 0.955
# validation accuracy: 0.7333333333333334
# ====================================
# Epoch [26/20], Step 10, Loss: 0.4082
# train accuracy: 0.9377777777777777
# validation accuracy: 0.6999999999999998
# ====================================
# epoch: 26
# Epoch [27/20], Step 5, Loss: 0.3490
# train accuracy: 0.96
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [27/20], Step 10, Loss: 0.3260
# train accuracy: 0.9600000000000001
# validation accuracy: 0.7666666666666666
# ====================================
# epoch: 27
# Epoch [28/20], Step 5, Loss: 0.3340
# train accuracy: 0.955
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [28/20], Step 10, Loss: 0.3541
# train accuracy: 0.9644444444444444
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 28
# Epoch [29/20], Step 5, Loss: 0.3159
# train accuracy: 0.965
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [29/20], Step 10, Loss: 0.3150
# train accuracy: 0.9688888888888889
# validation accuracy: 0.7999999999999999
# ====================================
# epoch: 29
# Epoch [30/20], Step 5, Loss: 0.3374
# train accuracy: 0.985
# validation accuracy: 0.7333333333333334
# ====================================
# Epoch [30/20], Step 10, Loss: 0.3148
# train accuracy: 0.9777777777777779
# validation accuracy: 0.7666666666666666
# ====================================
# epoch: 30
# Epoch [31/20], Step 5, Loss: 0.3341
# train accuracy: 0.995
# validation accuracy: 0.7333333333333334
# ====================================
# Epoch [31/20], Step 10, Loss: 0.3372
# train accuracy: 0.98
# validation accuracy: 0.7999999999999999
# ====================================
# epoch: 31
# Epoch [32/20], Step 5, Loss: 0.3459
# train accuracy: 0.985
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [32/20], Step 10, Loss: 0.3736
# train accuracy: 0.9822222222222222
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 32
# Epoch [33/20], Step 5, Loss: 0.3534
# train accuracy: 0.98
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [33/20], Step 10, Loss: 0.3342
# train accuracy: 0.9822222222222224
# validation accuracy: 0.7666666666666666
# ====================================
# epoch: 33
# Epoch [34/20], Step 5, Loss: 0.3337
# train accuracy: 0.99
# validation accuracy: 0.7666666666666666
# ====================================
# Epoch [34/20], Step 10, Loss: 0.3354
# train accuracy: 0.9866666666666666
# validation accuracy: 0.7666666666666666
# ====================================
# epoch: 34
# Epoch [35/20], Step 5, Loss: 0.3136
# train accuracy: 0.995
# validation accuracy: 0.7999999999999999
# ====================================
# Epoch [35/20], Step 10, Loss: 0.3322
# train accuracy: 0.9888888888888889
# validation accuracy: 0.6666666666666666
# ====================================
# epoch: 35
# Epoch [36/20], Step 5, Loss: 0.3135
# train accuracy: 0.985
# validation accuracy: 0.7666666666666666
# ====================================
# Epoch [36/20], Step 10, Loss: 0.3549
# train accuracy: 0.9822222222222222
# validation accuracy: 0.7666666666666666
# ====================================
# epoch: 36
# Epoch [37/20], Step 5, Loss: 0.3336
# train accuracy: 0.985
# validation accuracy: 0.6666666666666666
# ====================================
# Epoch [37/20], Step 10, Loss: 0.3136
# train accuracy: 0.9844444444444446
# validation accuracy: 0.6666666666666666
# ====================================
# epoch: 37
# Epoch [38/20], Step 5, Loss: 0.3534
# train accuracy: 0.98
# validation accuracy: 0.8666666666666667
# ====================================
# Epoch [38/20], Step 10, Loss: 0.3734
# train accuracy: 0.98
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 38
# Epoch [39/20], Step 5, Loss: 0.3336
# train accuracy: 0.985
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [39/20], Step 10, Loss: 0.3388
# train accuracy: 0.9888888888888889
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 39
# Epoch [40/20], Step 5, Loss: 0.3138
# train accuracy: 0.99
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [40/20], Step 10, Loss: 0.3538
# train accuracy: 0.98
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 40
# Epoch [41/20], Step 5, Loss: 0.3144
# train accuracy: 0.99
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [41/20], Step 10, Loss: 0.3334
# train accuracy: 0.991111111111111
# validation accuracy: 0.7999999999999999
# ====================================
# epoch: 41
# Epoch [42/20], Step 5, Loss: 0.3334
# train accuracy: 0.98
# validation accuracy: 0.8666666666666667
# ====================================
# Epoch [42/20], Step 10, Loss: 0.3334
# train accuracy: 0.98
# validation accuracy: 0.8666666666666667
# ====================================
# epoch: 42
# Epoch [43/20], Step 5, Loss: 0.3533
# train accuracy: 0.98
# validation accuracy: 0.7999999999999999
# ====================================
# Epoch [43/20], Step 10, Loss: 0.3336
# train accuracy: 0.9866666666666668
# validation accuracy: 0.7999999999999999
# ====================================
# epoch: 43
# Epoch [44/20], Step 5, Loss: 0.3487
# train accuracy: 0.98
# validation accuracy: 0.7666666666666666
# ====================================
# Epoch [44/20], Step 10, Loss: 0.3134
# train accuracy: 0.9888888888888889
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 44
# Epoch [45/20], Step 5, Loss: 0.3333
# train accuracy: 0.99
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [45/20], Step 10, Loss: 0.3408
# train accuracy: 0.9866666666666666
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 45
# Epoch [46/20], Step 5, Loss: 0.3445
# train accuracy: 0.965
# validation accuracy: 0.9
# ====================================
# Epoch [46/20], Step 10, Loss: 0.3196
# train accuracy: 0.9755555555555555
# validation accuracy: 0.8666666666666667
# ====================================
# epoch: 46
# Epoch [47/20], Step 5, Loss: 0.3154
# train accuracy: 0.975
# validation accuracy: 0.8666666666666667
# ====================================
# Epoch [47/20], Step 10, Loss: 0.3837
# train accuracy: 0.9777777777777779
# validation accuracy: 0.8666666666666667
# ====================================
# epoch: 47
# Epoch [48/20], Step 5, Loss: 0.3335
# train accuracy: 0.985
# validation accuracy: 0.7333333333333334
# ====================================
# Epoch [48/20], Step 10, Loss: 0.3171
# train accuracy: 0.991111111111111
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 48
# Epoch [49/20], Step 5, Loss: 0.3135
# train accuracy: 0.975
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [49/20], Step 10, Loss: 0.3334
# train accuracy: 0.9844444444444446
# validation accuracy: 0.7666666666666666
# ====================================
# epoch: 49
# Epoch [50/20], Step 5, Loss: 0.4495
# train accuracy: 0.82
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [50/20], Step 10, Loss: 0.3925
# train accuracy: 0.8999999999999999
# validation accuracy: 0.7999999999999999
# ====================================
# epoch: 50
# Epoch [51/20], Step 5, Loss: 0.3536
# train accuracy: 0.975
# validation accuracy: 0.8666666666666667
# ====================================
# Epoch [51/20], Step 10, Loss: 0.3354
# train accuracy: 0.98
# validation accuracy: 0.7666666666666666
# ====================================
# epoch: 51
# Epoch [52/20], Step 5, Loss: 0.3335
# train accuracy: 0.975
# validation accuracy: 0.7333333333333334
# ====================================
# Epoch [52/20], Step 10, Loss: 0.3337
# train accuracy: 0.9844444444444446
# validation accuracy: 0.8666666666666667
# ====================================
# epoch: 52
# Epoch [53/20], Step 5, Loss: 0.3306
# train accuracy: 0.98
# validation accuracy: 0.8666666666666667
# ====================================
# Epoch [53/20], Step 10, Loss: 0.3135
# train accuracy: 0.9866666666666668
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 53
# Epoch [54/20], Step 5, Loss: 0.3538
# train accuracy: 0.985
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [54/20], Step 10, Loss: 0.3541
# train accuracy: 0.9844444444444443
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 54
# Epoch [55/20], Step 5, Loss: 0.3134
# train accuracy: 1.0
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [55/20], Step 10, Loss: 0.3535
# train accuracy: 0.9888888888888892
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 55
# Epoch [56/20], Step 5, Loss: 0.3134
# train accuracy: 0.995
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [56/20], Step 10, Loss: 0.3333
# train accuracy: 0.9888888888888889
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 56
# Epoch [57/20], Step 5, Loss: 0.3133
# train accuracy: 0.995
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [57/20], Step 10, Loss: 0.3333
# train accuracy: 0.9844444444444443
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 57
# Epoch [58/20], Step 5, Loss: 0.3133
# train accuracy: 0.98
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [58/20], Step 10, Loss: 0.3333
# train accuracy: 0.9866666666666668
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 58
# Epoch [59/20], Step 5, Loss: 0.3133
# train accuracy: 0.99
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [59/20], Step 10, Loss: 0.3133
# train accuracy: 0.9955555555555556
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 59
# Epoch [60/20], Step 5, Loss: 0.3133
# train accuracy: 0.995
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [60/20], Step 10, Loss: 0.3133
# train accuracy: 0.9888888888888889
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 60
# Epoch [61/20], Step 5, Loss: 0.3333
# train accuracy: 0.99
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [61/20], Step 10, Loss: 0.3333
# train accuracy: 0.9844444444444446
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 61
# Epoch [62/20], Step 5, Loss: 0.3133
# train accuracy: 0.995
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [62/20], Step 10, Loss: 0.3333
# train accuracy: 0.9955555555555556
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 62
# Epoch [63/20], Step 5, Loss: 0.3133
# train accuracy: 0.985
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [63/20], Step 10, Loss: 0.3333
# train accuracy: 0.9822222222222222
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 63
# Epoch [64/20], Step 5, Loss: 0.3333
# train accuracy: 0.985
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [64/20], Step 10, Loss: 0.3333
# train accuracy: 0.9866666666666668
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 64
# Epoch [65/20], Step 5, Loss: 0.3533
# train accuracy: 0.985
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [65/20], Step 10, Loss: 0.3133
# train accuracy: 0.9888888888888887
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 65
# Epoch [66/20], Step 5, Loss: 0.3133
# train accuracy: 0.995
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [66/20], Step 10, Loss: 0.3133
# train accuracy: 0.9933333333333335
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 66
# Epoch [67/20], Step 5, Loss: 0.3333
# train accuracy: 0.985
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [67/20], Step 10, Loss: 0.3333
# train accuracy: 0.9844444444444446
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 67
# Epoch [68/20], Step 5, Loss: 0.3133
# train accuracy: 0.99
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [68/20], Step 10, Loss: 0.3133
# train accuracy: 0.9933333333333333
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 68
# Epoch [69/20], Step 5, Loss: 0.3333
# train accuracy: 0.99
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [69/20], Step 10, Loss: 0.3333
# train accuracy: 0.9933333333333333
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 69
# Epoch [70/20], Step 5, Loss: 0.3133
# train accuracy: 0.995
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [70/20], Step 10, Loss: 0.3333
# train accuracy: 0.9888888888888889
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 70
# Epoch [71/20], Step 5, Loss: 0.3333
# train accuracy: 0.975
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [71/20], Step 10, Loss: 0.3133
# train accuracy: 0.9822222222222222
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 71
# Epoch [72/20], Step 5, Loss: 0.3533
# train accuracy: 0.985
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [72/20], Step 10, Loss: 0.3133
# train accuracy: 0.9866666666666668
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 72
# Epoch [73/20], Step 5, Loss: 0.3133
# train accuracy: 0.995
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [73/20], Step 10, Loss: 0.3533
# train accuracy: 0.991111111111111
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 73
# Epoch [74/20], Step 5, Loss: 0.3533
# train accuracy: 0.99
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [74/20], Step 10, Loss: 0.3133
# train accuracy: 0.9866666666666666
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 74
# Epoch [75/20], Step 5, Loss: 0.3533
# train accuracy: 0.975
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [75/20], Step 10, Loss: 0.3133
# train accuracy: 0.9866666666666666
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 75
# Epoch [76/20], Step 5, Loss: 0.3733
# train accuracy: 0.98
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [76/20], Step 10, Loss: 0.3133
# train accuracy: 0.9888888888888889
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 76
# Epoch [77/20], Step 5, Loss: 0.3333
# train accuracy: 0.99
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [77/20], Step 10, Loss: 0.3133
# train accuracy: 0.9955555555555556
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 77
# Epoch [78/20], Step 5, Loss: 0.3333
# train accuracy: 0.98
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [78/20], Step 10, Loss: 0.3133
# train accuracy: 0.9866666666666668
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 78
# Epoch [79/20], Step 5, Loss: 0.3333
# train accuracy: 0.985
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [79/20], Step 10, Loss: 0.3333
# train accuracy: 0.9866666666666668
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 79
# Epoch [80/20], Step 5, Loss: 0.3533
# train accuracy: 0.975
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [80/20], Step 10, Loss: 0.3133
# train accuracy: 0.9888888888888889
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 80
# Epoch [81/20], Step 5, Loss: 0.3133
# train accuracy: 0.985
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [81/20], Step 10, Loss: 0.3133
# train accuracy: 0.991111111111111
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 81
# Epoch [82/20], Step 5, Loss: 0.3333
# train accuracy: 0.985
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [82/20], Step 10, Loss: 0.3133
# train accuracy: 0.9888888888888889
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 82
# Epoch [83/20], Step 5, Loss: 0.3133
# train accuracy: 0.995
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [83/20], Step 10, Loss: 0.3333
# train accuracy: 0.9866666666666668
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 83
# Epoch [84/20], Step 5, Loss: 0.3133
# train accuracy: 0.995
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [84/20], Step 10, Loss: 0.3333
# train accuracy: 0.9933333333333333
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 84
# Epoch [85/20], Step 5, Loss: 0.3333
# train accuracy: 0.985
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [85/20], Step 10, Loss: 0.3133
# train accuracy: 0.9888888888888889
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 85
# Epoch [86/20], Step 5, Loss: 0.3133
# train accuracy: 0.995
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [86/20], Step 10, Loss: 0.3333
# train accuracy: 0.991111111111111
# validation accuracy: 0.8333333333333334
# ====================================
# epoch: 86
# Epoch [87/20], Step 5, Loss: 0.3533
# train accuracy: 0.985
# validation accuracy: 0.8333333333333334
# ====================================
# Epoch [87/20], Step 10, Loss: 0.3133
# train accuracy: 0.9866666666666668
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 87
# Epoch [88/20], Step 5, Loss: 0.3133
# train accuracy: 0.98
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [88/20], Step 10, Loss: 0.3133
# train accuracy: 0.9888888888888889
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 88
# Epoch [89/20], Step 5, Loss: 0.3333
# train accuracy: 0.98
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [89/20], Step 10, Loss: 0.3133
# train accuracy: 0.9844444444444446
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 89
# Epoch [90/20], Step 5, Loss: 0.3733
# train accuracy: 0.97
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [90/20], Step 10, Loss: 0.3333
# train accuracy: 0.9822222222222222
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 90
# Epoch [91/20], Step 5, Loss: 0.3333
# train accuracy: 0.99
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [91/20], Step 10, Loss: 0.3333
# train accuracy: 0.9888888888888889
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 91
# Epoch [92/20], Step 5, Loss: 0.3333
# train accuracy: 0.985
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [92/20], Step 10, Loss: 0.3133
# train accuracy: 0.9866666666666668
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 92
# Epoch [93/20], Step 5, Loss: 0.3533
# train accuracy: 0.985
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [93/20], Step 10, Loss: 0.3133
# train accuracy: 0.991111111111111
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 93
# Epoch [94/20], Step 5, Loss: 0.3133
# train accuracy: 1.0
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [94/20], Step 10, Loss: 0.3533
# train accuracy: 0.9911111111111113
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 94
# Epoch [95/20], Step 5, Loss: 0.3333
# train accuracy: 0.985
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [95/20], Step 10, Loss: 0.3333
# train accuracy: 0.9866666666666666
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 95
# Epoch [96/20], Step 5, Loss: 0.3533
# train accuracy: 0.98
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [96/20], Step 10, Loss: 0.3133
# train accuracy: 0.9866666666666668
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 96
# Epoch [97/20], Step 5, Loss: 0.3133
# train accuracy: 0.995
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [97/20], Step 10, Loss: 0.3333
# train accuracy: 0.9933333333333333
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 97
# Epoch [98/20], Step 5, Loss: 0.3333
# train accuracy: 0.98
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [98/20], Step 10, Loss: 0.3333
# train accuracy: 0.9844444444444443
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 98
# Epoch [99/20], Step 5, Loss: 0.3133
# train accuracy: 0.99
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [99/20], Step 10, Loss: 0.3133
# train accuracy: 0.9888888888888887
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 99
# Epoch [100/20], Step 5, Loss: 0.3333
# train accuracy: 0.98
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [100/20], Step 10, Loss: 0.3133
# train accuracy: 0.9888888888888889
# validation accuracy: 0.8000000000000002
# ====================================
# epoch: 100
# Epoch [101/20], Step 5, Loss: 0.3133
# train accuracy: 0.995
# validation accuracy: 0.8000000000000002
# ====================================
# Epoch [101/20], Step 10, Loss: 0.3333
# train accuracy: 0.991111111111111
# validation accuracy: 0.8000000000000002
# ====================================
