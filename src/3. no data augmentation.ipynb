# %%
#part of the code is from https://github.com/maciejkula/triplet_recommendations_keras

import numpy as np
import pandas as pd
import os
import glob
from collections import defaultdict
from sklearn.model_selection import train_test_split
from sklearn.neighbors import NearestNeighbors
from PIL import Image
from keras import backend as K
from keras import optimizers, losses, activations, models
from keras.models import Model
from keras.optimizers import Adam
from keras.layers import Embedding, Flatten, Input, merge
from keras.layers import Conv2D, MaxPooling2D, Dense, GlobalMaxPooling2D
from keras.layers import Convolution2D, Dropout, BatchNormalization, \
    GlobalMaxPool2D, Concatenate, GlobalAveragePooling2D, Lambda
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau, TensorBoard
from keras.applications.resnet50 import ResNet50

K.set_session(K.tf.Session(config=K.tf.ConfigProto(intra_op_parallelism_threads=10, inter_op_parallelism_threads=10)))
# Out:
# Using TensorFlow backend.

# %%
class sample_gen(object):
    def __init__(self, file_class_mapping, other_class = "new_whale"):
        self.file_class_mapping= file_class_mapping
        self.class_to_list_files = defaultdict(list)
        self.list_other_class = []
        self.list_all_files = list(file_class_mapping.keys())
        self.range_all_files = list(range(len(self.list_all_files)))

        for file, class_ in file_class_mapping.items():
            if class_ == other_class:
                self.list_other_class.append(file)
            else:
                self.class_to_list_files[class_].append(file)

        self.list_classes = list(set(self.file_class_mapping.values()))
        self.range_list_classes= range(len(self.list_classes))
        self.class_weight = np.array([len(self.class_to_list_files[class_]) for class_ in self.list_classes])
        self.class_weight = self.class_weight/np.sum(self.class_weight)

    def get_sample(self):
        class_idx = np.random.choice(self.range_list_classes, 1, p=self.class_weight)[0]
        examples_class_idx = np.random.choice(range(len(self.class_to_list_files[self.list_classes[class_idx]])), 2)
        positive_example_1, positive_example_2 = \
            self.class_to_list_files[self.list_classes[class_idx]][examples_class_idx[0]],\
            self.class_to_list_files[self.list_classes[class_idx]][examples_class_idx[1]]


        negative_example = None
        while negative_example is None or self.file_class_mapping[negative_example] == \
                self.file_class_mapping[positive_example_1]:
            negative_example_idx = np.random.choice(self.range_all_files, 1)[0]
            negative_example = self.list_all_files[negative_example_idx]
        return positive_example_1, negative_example, positive_example_2

# %%
def identity_loss(y_true, y_pred):

    return K.mean(y_pred - 0 * y_true)


def bpr_triplet_loss(X):

    positive_item_latent, negative_item_latent, user_latent = X

    # BPR loss
    loss = 1.0 - K.sigmoid(
        K.sum(user_latent * positive_item_latent, axis=-1, keepdims=True) -
        K.sum(user_latent * negative_item_latent, axis=-1, keepdims=True))

    return loss

def get_base_model():
    latent_dim = 50
    base_model = ResNet50(include_top=False, weights='imagenet') # use weights='imagenet' locally

    # for layer in base_model.layers:
    #     layer.trainable = False

    x = base_model.output
    x = GlobalMaxPooling2D()(x)
    x = Dropout(0.5)(x)
    dense_1 = Dense(latent_dim)(x)
    normalized = Lambda(lambda  x: K.l2_normalize(x, axis=1))(dense_1)
    base_model = Model(base_model.input, normalized, name="base_model")
    return base_model

def build_model():
    base_model = get_base_model()

    positive_example_1 = Input(input_shape+(3,) , name='positive_example_1')
    negative_example = Input(input_shape+(3,), name='negative_example')
    positive_example_2 = Input(input_shape+(3,), name='positive_example_2')

    positive_example_1_out = base_model(positive_example_1)
    negative_example_out = base_model(negative_example)
    positive_example_2_out = base_model(positive_example_2)

    loss = merge(
        [positive_example_1_out, negative_example_out, positive_example_2_out],
        mode=bpr_triplet_loss,
        name='loss',
        output_shape=(1, ))

    model = Model(
        input=[positive_example_1, negative_example, positive_example_2],
        output=loss)
    model.compile(loss=identity_loss, optimizer=Adam(0.000001))

    print(model.summary())

    return model

# %%
def build_inference_model(weight_path):
    base_model = get_base_model()

    positive_example_1 = Input(input_shape+(3,) , name='positive_example_1')
    negative_example = Input(input_shape+(3,), name='negative_example')
    positive_example_2 = Input(input_shape+(3,), name='positive_example_2')

    positive_example_1_out = base_model(positive_example_1)
    negative_example_out = base_model(negative_example)
    positive_example_2_out = base_model(positive_example_2)

    loss = merge(
        [positive_example_1_out, negative_example_out, positive_example_2_out],
        mode=bpr_triplet_loss,
        name='loss',
        output_shape=(1, ))

    model = Model(
        input=[positive_example_1, negative_example, positive_example_2],
        output=loss)
    model.compile(loss=identity_loss, optimizer=Adam(0.000001))

    model.load_weights(weight_path)

    inference_model = Model(base_model.get_input_at(0), output=base_model.get_output_at(0))
    inference_model.compile(loss="mse", optimizer=Adam(0.000001))
    print(inference_model.summary())

    return inference_model

def read_and_resize(filepath):
    im = Image.open((filepath)).convert('RGB')
    im = im.resize(input_shape)
    im_array = np.array(im, dtype="uint8")[..., ::-1]
    return np.array(im_array / (np.max(im_array)+ 0.001), dtype="float32")


def augment(im_array):
    if np.random.uniform(0, 1) > 0.9:
        im_array = np.fliplr(im_array)
    return im_array

def gen(triplet_gen):
    while True:
        list_positive_examples_1 = []
        list_negative_examples = []
        list_positive_examples_2 = []

        for i in range(batch_size):
            positive_example_1, negative_example, positive_example_2 = triplet_gen.get_sample()
            positive_example_1_img, negative_example_img, positive_example_2_img = read_and_resize(base_path+positive_example_1), \
                                                                       read_and_resize(base_path+negative_example), \
                                                                       read_and_resize(base_path+positive_example_2)

            positive_example_1_img, negative_example_img, positive_example_2_img = augment(positive_example_1_img), \
                                                                                   augment(negative_example_img), \
                                                                                   augment(positive_example_2_img)

            list_positive_examples_1.append(positive_example_1_img)
            list_negative_examples.append(negative_example_img)
            list_positive_examples_2.append(positive_example_2_img)

        list_positive_examples_1 = np.array(list_positive_examples_1)
        list_negative_examples = np.array(list_negative_examples)
        list_positive_examples_2 = np.array(list_positive_examples_2)
        yield [list_positive_examples_1, list_negative_examples, list_positive_examples_2], np.ones(batch_size)

# %%
def data_generator(fpaths, batch=16):
    i = 0
    for path in fpaths:
        if i == 0:
            imgs = []
            fnames = []
        i += 1
        img = read_and_resize(path)
        imgs.append(img)
        fnames.append(os.path.basename(path))
        if i == batch:
            i = 0
            imgs = np.array(imgs)
            yield fnames, imgs
    if i < batch:
        imgs = np.array(imgs)
        yield fnames, imgs
    raise StopIteration()

# %%
batch_size = 8
input_shape = (224, 224)
base_path = "../dataset/train/"
model_name = "triplet_model"

file_path = model_name + "weights.best.hdf5"

# %%
num_epochs = 50

# Read data
data = pd.read_csv('train.csv')
train, test = train_test_split(data, test_size=0.3, shuffle=True, random_state=1337)
file_id_mapping_train = {k: v for k, v in zip(train.Image.values, train.Id.values)}
file_id_mapping_test = {k: v for k, v in zip(test.Image.values, test.Id.values)}
train_gen = sample_gen(file_id_mapping_train)
test_gen = sample_gen(file_id_mapping_test)



# Prepare the test triplets

model = build_model()

checkpoint = ModelCheckpoint(file_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

early = EarlyStopping(monitor="val_loss", mode="min", patience=2)

callbacks_list = [checkpoint, early]  # early

history = model.fit_generator(gen(train_gen), validation_data=gen(test_gen), epochs=150, verbose=2, workers=4,
                              callbacks=callbacks_list, steps_per_epoch=300, validation_steps=30)
                              
                              
model_name = "triplet_loss"
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:47: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /home/user/.local/lib/python3.5/site-packages/keras/legacy/layers.py:465: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:51: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("lo..., inputs=[<tf.Tenso...)`
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# positive_example_1 (InputLayer) (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# negative_example (InputLayer)   (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# positive_example_2 (InputLayer) (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# base_model (Model)              (None, 50)           23690162    positive_example_1[0][0]
#                                                                  negative_example[0][0]
#                                                                  positive_example_2[0][0]
# __________________________________________________________________________________________________
# loss (Merge)                    (None, 1)            0           base_model[1][0]
#                                                                  base_model[2][0]
#                                                                  base_model[3][0]
# ==================================================================================================
# Total params: 23,690,162
# Trainable params: 23,637,042
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# None
# Epoch 1/150
#  - 148s - loss: 0.4579 - val_loss: 0.3749
#
# Epoch 00001: val_loss improved from inf to 0.37495, saving model to triplet_modelweights.best.hdf5
# Epoch 2/150
#  - 125s - loss: 0.4574 - val_loss: 0.3784
#
# Epoch 00002: val_loss did not improve from 0.37495
# Epoch 3/150
#  - 124s - loss: 0.4535 - val_loss: 0.3643
#
# Epoch 00003: val_loss improved from 0.37495 to 0.36432, saving model to triplet_modelweights.best.hdf5
# Epoch 4/150
#  - 124s - loss: 0.4478 - val_loss: 0.3547
#
# Epoch 00004: val_loss improved from 0.36432 to 0.35475, saving model to triplet_modelweights.best.hdf5
# Epoch 5/150
#  - 124s - loss: 0.4427 - val_loss: 0.3867
#
# Epoch 00005: val_loss did not improve from 0.35475
# Epoch 6/150
#  - 124s - loss: 0.4372 - val_loss: 0.3499
#
# Epoch 00006: val_loss improved from 0.35475 to 0.34988, saving model to triplet_modelweights.best.hdf5
# Epoch 7/150
#  - 124s - loss: 0.4316 - val_loss: 0.4987
#
# Epoch 00007: val_loss did not improve from 0.34988
# Epoch 8/150
#  - 124s - loss: 0.4251 - val_loss: 0.3341
#
# Epoch 00008: val_loss improved from 0.34988 to 0.33415, saving model to triplet_modelweights.best.hdf5
# Epoch 9/150
#  - 124s - loss: 0.4204 - val_loss: 0.3266
#
# Epoch 00009: val_loss improved from 0.33415 to 0.32658, saving model to triplet_modelweights.best.hdf5
# Epoch 10/150
#  - 124s - loss: 0.4148 - val_loss: 0.3116
#
# Epoch 00010: val_loss improved from 0.32658 to 0.31156, saving model to triplet_modelweights.best.hdf5
# Epoch 11/150
#  - 124s - loss: 0.4081 - val_loss: 0.4625
#
# Epoch 00011: val_loss did not improve from 0.31156
# Epoch 12/150
#  - 124s - loss: 0.4029 - val_loss: 0.3314
#
# Epoch 00012: val_loss did not improve from 0.31156

# %%
data = pd.read_csv('train.csv')

file_id_mapping = {k: v for k, v in zip(data.Image.values, data.Id.values)}

inference_model = build_inference_model(file_path)

train_files = glob.glob("../dataset/train/*.jpg")
test_files = glob.glob("../dataset/test/*.jpg")

train_preds = []
train_file_names = []
i = 1
for fnames, imgs in data_generator(train_files, batch=32):
    print(i*32/len(train_files)*100)
    i += 1
    predicts = inference_model.predict(imgs)
    predicts = predicts.tolist()
    train_preds += predicts
    train_file_names += fnames

train_preds = np.array(train_preds)

test_preds = []
test_file_names = []
i = 1
for fnames, imgs in data_generator(test_files, batch=32):
    print(i * 32 / len(test_files) * 100)
    i += 1
    predicts = inference_model.predict(imgs)
    predicts = predicts.tolist()
    test_preds += predicts
    test_file_names += fnames

test_preds = np.array(test_preds)

neigh = NearestNeighbors(n_neighbors=6)
neigh.fit(train_preds)
#distances, neighbors = neigh.kneighbors(train_preds)

#print(distances, neighbors)

distances_test, neighbors_test = neigh.kneighbors(test_preds)

distances_test, neighbors_test = distances_test.tolist(), neighbors_test.tolist()

preds_str = []

for filepath, distance, neighbour_ in zip(test_file_names, distances_test, neighbors_test):
    sample_result = []
    sample_classes = []
    for d, n in zip(distance, neighbour_):
        train_file = train_files[n].split(os.sep)[-1]
        class_train = file_id_mapping[train_file]
        sample_classes.append(class_train)
        sample_result.append((class_train, d))

    if "new_whale" not in sample_classes:
        sample_result.append(("new_whale", 0.1))
    sample_result.sort(key=lambda x: x[1])
    sample_result = sample_result[:5]
    preds_str.append(" ".join([x[0] for x in sample_result]))

df = pd.DataFrame(preds_str, columns=["Id"])
df['Image'] = [x.split(os.sep)[-1] for x in test_file_names]
df.to_csv("150epoch.csv", index=False)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:16: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   app.launch_new_instance()
# /home/user/.local/lib/python3.5/site-packages/keras/legacy/layers.py:465: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:20: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("lo..., inputs=[<tf.Tenso...)`
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:25: UserWarning: Update your `Model` call to the Keras 2 API: `Model(Tensor("in..., outputs=Tensor("la...)`
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 6 0           activation_50[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_51[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_52[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, None, None, 2 0           add_17[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_53[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_54[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_55[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, None, None, 2 0           add_18[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_56[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_57[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_58[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, None, None, 2 0           add_19[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_60[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_61[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, None, None, 5 0           add_20[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_62[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_63[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_64[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_62[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, None, None, 5 0           add_21[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_65[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_66[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_67[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_65[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, None, None, 5 0           add_22[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_68[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_69[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_70[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_68[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, None, None, 5 0           add_23[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_72[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_73[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, None, None, 1 0           add_24[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_74[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_75[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_76[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_74[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, None, None, 1 0           add_25[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_77[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_78[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_79[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_77[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, None, None, 1 0           add_26[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_80[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_81[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_82[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, None, None, 1 0           add_27[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_83[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_84[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_85[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, None, None, 1 0           add_28[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_86[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_87[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_88[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_86[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, None, None, 1 0           add_29[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, None, None, 5 524800      activation_89[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, None, None, 5 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, None, None, 5 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_90[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, None, None, 5 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, None, None, 5 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_91[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, None, None, 2 2099200     activation_89[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, None, None, 2 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, None, None, 2 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, None, None, 2 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, None, None, 2 0           add_30[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, None, None, 5 1049088     activation_92[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, None, None, 5 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, None, None, 5 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_93[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, None, None, 5 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, None, None, 5 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_94[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, None, None, 2 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, None, None, 2 0           bn5b_branch2c[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, None, None, 2 0           add_31[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, None, None, 5 1049088     activation_95[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, None, None, 5 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, None, None, 5 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_96[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, None, None, 5 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, None, None, 5 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_97[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, None, None, 2 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, None, None, 2 0           bn5c_branch2c[0][0]
#                                                                  activation_95[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, None, None, 2 0           add_32[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, None, None, 2 0           activation_98[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_2 (GlobalM (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 2048)         0           global_max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 50)           102450      dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 50)           0           dense_2[0][0]
# ==================================================================================================
# Total params: 23,690,162
# Trainable params: 23,637,042
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# None
# 0.3248730964467005
# 0.649746192893401
# 0.9746192893401016
# 1.299492385786802
# 1.6243654822335025
# 1.9492385786802031
# 2.2741116751269037
# 2.598984771573604
# 2.9238578680203045
# 3.248730964467005
# 3.5736040609137056
# 3.8984771573604062
# 4.223350253807107
# 4.548223350253807
# 4.873096446700507
# 5.197969543147208
# 5.522842639593908
# 5.847715736040609
# 6.1725888324873095
# 6.49746192893401
# 6.82233502538071
# 7.147208121827411
# 7.472081218274111
# 7.7969543147208125
# 8.121827411167512
# 8.446700507614214
# 8.771573604060915
# 9.096446700507615
# 9.421319796954315
# 9.746192893401014
# 10.071065989847716
# 10.395939086294415
# 10.720812182741117
# 11.045685279187817
# 11.370558375634518
# 11.695431472081218
# 12.02030456852792
# 12.345177664974619
# 12.67005076142132
# 12.99492385786802
# 13.319796954314722
# 13.64467005076142
# 13.969543147208121
# 14.294416243654823
# 14.619289340101524
# 14.944162436548222
# 15.269035532994923
# 15.593908629441625
# 15.918781725888326
# 16.243654822335024
# 16.568527918781726
# 16.893401015228427
# 17.21827411167513
# 17.54314720812183
# 17.868020304568528
# 18.19289340101523
# 18.517766497461928
# 18.84263959390863
# 19.16751269035533
# 19.49238578680203
# 19.81725888324873
# 20.14213197969543
# 20.46700507614213
# 20.79187817258883
# 21.116751269035532
# 21.441624365482234
# 21.766497461928935
# 22.091370558375633
# 22.416243654822335
# 22.741116751269036
# 23.065989847715738
# 23.390862944162436
# 23.715736040609137
# 24.04060913705584
# 24.36548223350254
# 24.690355329949238
# 25.015228426395943
# 25.34010152284264
# 25.66497461928934
# 25.98984771573604
# 26.314720812182742
# 26.639593908629443
# 26.96446700507614
# 27.28934010152284
# 27.614213197969544
# 27.939086294416242
# 28.26395939086294
# 28.588832487309645
# 28.913705583756343
# 29.238578680203048
# 29.563451776649746
# 29.888324873096444
# 30.21319796954315
# 30.538071065989847
# 30.862944162436552
# 31.18781725888325
# 31.512690355329948
# 31.837563451776653
# 32.16243654822335
# 32.48730964467005
# 32.81218274111675
# 33.13705583756345
# 33.46192893401015
# 33.786802030456855
# 34.11167512690355
# 34.43654822335026
# 34.76142131979695
# 35.08629441624366
# 35.411167512690355
# 35.736040609137056
# 36.06091370558376
# 36.38578680203046
# 36.710659898477154
# 37.035532994923855
# 37.36040609137056
# 37.68527918781726
# 38.01015228426396
# 38.33502538071066
# 38.65989847715736
# 38.98477157360406
# 39.309644670050766
# 39.63451776649746
# 39.95939086294416
# 40.28426395939086
# 40.609137055837564
# 40.93401015228426
# 41.25888324873097
# 41.58375634517766
# 41.90862944162437
# 42.233502538071065
# 42.558375634517766
# 42.88324873096447
# 43.20812182741117
# 43.53299492385787
# 43.85786802030457
# 44.18274111675127
# 44.50761421319797
# 44.83248730964467
# 45.15736040609137
# 45.48223350253807
# 45.807106598984774
# 46.131979695431475
# 46.45685279187817
# 46.78172588832487
# 47.10659898477157
# 47.431472081218274
# 47.756345177664976
# 48.08121827411168
# 48.40609137055837
# 48.73096446700508
# 49.055837563451774
# 49.380710659898476
# 49.70558375634518
# 50.030456852791886
# 50.35532994923858
# 50.68020304568528
# 51.005076142131976
# 51.32994923857868
# 51.654822335025386
# 51.97969543147208
# 52.30456852791878
# 52.629441624365484
# 52.95431472081218
# 53.27918781725889
# 53.60406091370559
# 53.92893401015228
# 54.253807106598984
# 54.57868020304568
# 54.90355329949238
# 55.22842639593909
# 55.55329949238579
# 55.878172588832484
# 56.203045685279186
# 56.52791878172588
# 56.852791878172596
# 57.17766497461929
# 57.50253807106599
# 57.827411167512686
# 58.15228426395939
# 58.477157360406096
# 58.80203045685279
# 59.12690355329949
# 59.45177664974619
# 59.77664974619289
# 60.101522842639596
# 60.4263959390863
# 60.75126903553299
# 61.076142131979694
# 61.401015228426395
# 61.725888324873104
# 62.0507614213198
# 62.3756345177665
# 62.700507614213194
# 63.025380710659896
# 63.3502538071066
# 63.675126903553306
# 64.0
# 64.3248730964467
# 64.6497461928934
# 64.9746192893401
# 65.2994923857868
# 65.6243654822335
# 65.94923857868021
# 66.2741116751269
# 66.5989847715736
# 66.9238578680203
# 67.248730964467
# 67.57360406091371
# 67.8984771573604
# 68.2233502538071
# 68.5482233502538
# 68.87309644670052
# 69.19796954314721
# 69.5228426395939
# 69.84771573604061
# 70.17258883248732
# 70.49746192893402
# 70.82233502538071
# 71.1472081218274
# 71.47208121827411
# 71.79695431472081
# 72.12182741116752
# 72.44670050761421
# 72.77157360406092
# 73.09644670050761
# 73.42131979695431
# 73.74619289340102
# 74.07106598984771
# 74.39593908629442
# 74.72081218274111
# 75.04568527918781
# 75.37055837563452
# 75.69543147208122
# 76.02030456852792
# 76.34517766497461
# 76.67005076142132
# 76.99492385786803
# 77.31979695431473
# 77.64467005076142
# 77.96954314720811
# 78.29441624365482
# 78.61928934010153
# 78.94416243654823
# 79.26903553299492
# 79.59390862944163
# 79.91878172588832
# 80.24365482233502
# 80.56852791878173
# 80.89340101522843
# 81.21827411167513
# 81.54314720812182
# 81.86802030456852
# 82.19289340101523
# 82.51776649746193
# 82.84263959390863
# 83.16751269035532
# 83.49238578680203
# 83.81725888324874
# 84.14213197969544
# 84.46700507614213
# 84.79187817258882
# 85.11675126903553
# 85.44162436548224
# 85.76649746192894
# 86.09137055837563
# 86.41624365482234
# 86.74111675126903
# 87.06598984771574
# 87.39086294416244
# 87.71573604060914
# 88.04060913705584
# 88.36548223350253
# 88.69035532994923
# 89.01522842639594
# 89.34010152284264
# 89.66497461928934
# 89.98984771573603
# 90.31472081218274
# 90.63959390862945
# 90.96446700507614
# 91.28934010152284
# 91.61421319796955
# 91.93908629441624
# 92.26395939086295
# 92.58883248730965
# 92.91370558375634
# 93.23857868020305
# 93.56345177664974
# 93.88832487309645
# 94.21319796954315
# 94.53807106598985
# 94.86294416243655
# 95.18781725888324
# 95.51269035532995
# 95.83756345177665
# 96.16243654822335
# 96.48730964467005
# 96.81218274111674
# 97.13705583756345
# 97.46192893401016
# 97.78680203045685
# 98.11167512690355
# 98.43654822335026
# 98.76142131979695
# 99.08629441624366
# 99.41116751269035
# 99.73604060913705
# 100.06091370558377
# 0.20499679692504805
# 0.4099935938500961
# 0.6149903907751442
# 0.8199871877001922
# 1.0249839846252402
# 1.2299807815502883
# 1.4349775784753362
# 1.6399743754003844
# 1.8449711723254325
# 2.0499679692504804
# 2.2549647661755285
# 2.4599615631005767
# 2.6649583600256244
# 2.8699551569506725
# 3.074951953875721
# 3.2799487508007688
# 3.4849455477258164
# 3.689942344650865
# 3.8949391415759127
# 4.099935938500961
# 4.304932735426009
# 4.509929532351057
# 4.714926329276105
# 4.919923126201153
# 5.1249199231262015
# 5.329916720051249
# 5.534913516976298
# 5.739910313901345
# 5.944907110826393
# 6.149903907751442
# 6.3549007046764885
# 6.5598975016015375
# 6.764894298526586
# 6.969891095451633
# 7.174887892376682
# 7.37988468930173
# 7.584881486226777
# 7.789878283151825
# 7.994875080076874
# 8.199871877001922
# 8.40486867392697
# 8.609865470852018
# 8.814862267777066
# 9.019859064702114
# 9.224855861627162
# 9.42985265855221
# 9.634849455477259
# 9.839846252402307
# 10.044843049327353
# 10.249839846252403
# 10.454836643177451
# 10.659833440102497
# 10.864830237027547
# 11.069827033952595
# 11.274823830877642
# 11.47982062780269
# 11.68481742472774
# 11.889814221652786
# 12.094811018577834
# 12.299807815502884
# 12.50480461242793
# 12.709801409352977
# 12.914798206278027
# 13.119795003203075
# 13.324791800128121
# 13.529788597053171
# 13.73478539397822
# 13.939782190903266
# 14.144778987828316
# 14.349775784753364
# 14.55477258167841
# 14.75976937860346
# 14.964766175528506
# 15.169762972453555
# 15.374759769378604
# 15.57975656630365
# 15.784753363228699
# 15.989750160153749
# 16.194746957078795
# 16.399743754003843
# 16.60474055092889
# 16.80973734785394
# 17.014734144778988
# 17.219730941704036
# 17.424727738629084
# 17.629724535554132
# 17.83472133247918
# 18.03971812940423
# 18.244714926329276
# 18.449711723254325
# 18.654708520179373
# 18.85970531710442
# 19.06470211402947
# 19.269698910954517
# 19.47469570787956
# 19.679692504804613
# 19.88468930172966
# 20.089686098654706
# 20.294682895579758
# 20.499679692504806
# 20.70467648942985
# 20.909673286354902
# 21.11467008327995
# 21.319666880204995
# 21.524663677130047
# 21.729660474055095
# 21.93465727098014
# 22.13965406790519
# 22.344650864830236
# 22.549647661755284
# 22.754644458680335
# 22.95964125560538
# 23.164638052530428
# 23.36963484945548
# 23.574631646380524
# 23.779628443305572
# 23.984625240230624
# 24.18962203715567
# 24.394618834080717
# 24.59961563100577
# 24.804612427930813
# 25.00960922485586
# 25.21460602178091
# 25.419602818705954
# 25.624599615631006
# 25.829596412556054
# 26.0345932094811
# 26.23959000640615
# 26.444586803331198
# 26.649583600256243
# 26.854580397181294
# 27.059577194106343
# 27.264573991031387
# 27.46957078795644
# 27.674567584881487
# 27.87956438180653
# 28.084561178731583
# 28.28955797565663
# 28.494554772581676
# 28.699551569506728
# 28.904548366431776
# 29.10954516335682
# 29.314541960281872
# 29.51953875720692
# 29.724535554131965
# 29.929532351057013
# 30.134529147982065
# 30.33952594490711
# 30.544522741832157
# 30.74951953875721
# 30.954516335682253
# 31.1595131326073
# 31.364509929532353
# 31.569506726457398
# 31.774503523382446
# 31.979500320307498
# 32.18449711723254
# 32.38949391415759
# 32.59449071108264
# 32.79948750800769
# 33.00448430493274
# 33.20948110185778
# 33.41447789878283
# 33.61947469570788
# 33.82447149263293
# 34.029468289557975
# 34.23446508648303
# 34.43946188340807
# 34.644458680333116
# 34.84945547725817
# 35.05445227418322
# 35.259449071108264
# 35.46444586803331
# 35.66944266495836
# 35.874439461883405
# 36.07943625880846
# 36.28443305573351
# 36.48942985265855
# 36.6944266495836
# 36.89942344650865
# 37.104420243433694
# 37.309417040358746
# 37.5144138372838
# 37.71941063420884
# 37.924407431133886
# 38.12940422805894
# 38.33440102498398
# 38.539397821909034
# 38.744394618834086
# 38.94939141575912
# 39.154388212684175
# 39.35938500960923
# 39.56438180653427
# 39.76937860345932
# 39.97437540038437
# 40.17937219730941
# 40.384368994234464
# 40.589365791159516
# 40.79436258808456
# 40.99935938500961
# 41.204356181934656
# 41.4093529788597
# 41.61434977578475
# 41.819346572709804
# 42.02434336963485
# 42.2293401665599
# 42.434336963484945
# 42.63933376040999
# 42.84433055733504
# 43.04932735426009
# 43.25432415118514
# 43.45932094811019
# 43.664317745035234
# 43.86931454196028
# 44.07431133888533
# 44.27930813581038
# 44.48430493273543
# 44.68930172966047
# 44.89429852658552
# 45.09929532351057
# 45.30429212043562
# 45.50928891736067
# 45.714285714285715
# 45.91928251121076
# 46.12427930813581
# 46.329276105060856
# 46.53427290198591
# 46.73926969891096
# 46.944266495836004
# 47.14926329276105
# 47.3542600896861
# 47.559256886611145
# 47.7642536835362
# 47.96925048046125
# 48.17424727738629
# 48.37924407431134
# 48.58424087123639
# 48.789237668161434
# 48.994234465086485
# 49.19923126201154
# 49.404228058936575
# 49.609224855861626
# 49.81422165278668
# 50.01921844971172
# 50.224215246636774
# 50.42921204356182
# 50.63420884048687
# 50.83920563741191
# 51.04420243433696
# 51.24919923126201
# 51.45419602818706
# 51.65919282511211
# 51.86418962203716
# 52.0691864189622
# 52.27418321588725
# 52.4791800128123
# 52.68417680973735
# 52.889173606662396
# 53.09417040358745
# 53.299167200512485
# 53.50416399743754
# 53.70916079436259
# 53.91415759128763
# 54.119154388212685
# 54.32415118513774
# 54.529147982062774
# 54.734144778987826
# 54.93914157591288
# 55.14413837283792
# 55.349135169762974
# 55.554131966688026
# 55.75912876361306
# 55.964125560538115
# 56.169122357463166
# 56.37411915438821
# 56.57911595131326
# 56.784112748238314
# 56.98910954516335
# 57.1941063420884
# 57.399103139013455
# 57.6040999359385
# 57.80909673286355
# 58.0140935297886
# 58.21909032671364
# 58.42408712363869
# 58.629083920563744
# 58.83408071748879
# 59.03907751441384
# 59.24407431133889
# 59.44907110826393
# 59.65406790518898
# 59.859064702114026
# 60.06406149903908
# 60.26905829596413
# 60.47405509288918
# 60.67905188981422
# 60.88404868673927
# 61.089045483664314
# 61.294042280589366
# 61.49903907751442
# 61.70403587443947
# 61.90903267136451
# 62.11402946828956
# 62.3190262652146
# 62.524023062139655
# 62.72901985906471
# 62.93401665598976
# 63.139013452914796
# 63.34401024983984
# 63.54900704676489
# 63.754003843689944
# 63.959000640614995
# 64.16399743754005
# 64.36899423446508
# 64.57399103139014
# 64.77898782831518
# 64.98398462524023
# 65.18898142216528
# 65.39397821909033
# 65.59897501601537
# 65.80397181294042
# 66.00896860986548
# 66.21396540679052
# 66.41896220371557
# 66.62395900064062
# 66.82895579756565
# 67.03395259449071
# 67.23894939141576
# 67.4439461883408
# 67.64894298526586
# 67.8539397821909
# 68.05893657911595
# 68.263933376041
# 68.46893017296605
# 68.6739269698911
# 68.87892376681614
# 69.0839205637412
# 69.28891736066623
# 69.49391415759129
# 69.69891095451634
# 69.90390775144138
# 70.10890454836644
# 70.31390134529148
# 70.51889814221653
# 70.72389493914157
# 70.92889173606662
# 71.13388853299168
# 71.33888532991672
# 71.54388212684178
# 71.74887892376681
# 71.95387572069187
# 72.15887251761691
# 72.36386931454196
# 72.56886611146702
# 72.77386290839206
# 72.9788597053171
# 73.18385650224215
# 73.3888532991672
# 73.59385009609225
# 73.7988468930173
# 74.00384368994236
# 74.20884048686739
# 74.41383728379243
# 74.61883408071749
# 74.82383087764254
# 75.0288276745676
# 75.23382447149262
# 75.43882126841768
# 75.64381806534273
# 75.84881486226777
# 76.05381165919283
# 76.25880845611788
# 76.46380525304292
# 76.66880204996797
# 76.87379884689301
# 77.07879564381807
# 77.28379244074311
# 77.48878923766817
# 77.6937860345932
# 77.89878283151825
# 78.1037796284433
# 78.30877642536835
# 78.51377322229341
# 78.71877001921845
# 78.9237668161435
# 79.12876361306854
# 79.33376040999359
# 79.53875720691865
# 79.74375400384369
# 79.94875080076874
# 80.15374759769378
# 80.35874439461882
# 80.56374119154388
# 80.76873798846893
# 80.97373478539399
# 81.17873158231903
# 81.38372837924408
# 81.58872517616912
# 81.79372197309416
# 81.99871877001922
# 82.20371556694427
# 82.40871236386931
# 82.61370916079436
# 82.8187059577194
# 83.02370275464446
# 83.2286995515695
# 83.43369634849455
# 83.63869314541961
# 83.84368994234464
# 84.0486867392697
# 84.25368353619474
# 84.4586803331198
# 84.66367713004485
# 84.86867392696989
# 85.07367072389494
# 85.27866752081998
# 85.48366431774504
# 85.68866111467008
# 85.89365791159513
# 86.09865470852019
# 86.30365150544522
# 86.50864830237028
# 86.71364509929532
# 86.91864189622038
# 87.12363869314542
# 87.32863549007047
# 87.53363228699551
# 87.73862908392056
# 87.94362588084562
# 88.14862267777066
# 88.3536194746957
# 88.55861627162076
# 88.7636130685458
# 88.96860986547085
# 89.1736066623959
# 89.37860345932094
# 89.583600256246
# 89.78859705317105
# 89.99359385009609
# 90.19859064702113
# 90.4035874439462
# 90.60858424087124
# 90.81358103779628
# 91.01857783472134
# 91.22357463164637
# 91.42857142857143
# 91.63356822549648
# 91.83856502242152
# 92.04356181934658
# 92.24855861627162
# 92.45355541319667
# 92.65855221012171
# 92.86354900704677
# 93.06854580397182
# 93.27354260089686
# 93.47853939782192
# 93.68353619474695
# 93.88853299167201
# 94.09352978859705
# 94.2985265855221
# 94.50352338244716
# 94.7085201793722
# 94.91351697629725
# 95.11851377322229
# 95.32351057014733
# 95.5285073670724
# 95.73350416399744
# 95.9385009609225
# 96.14349775784753
# 96.34849455477259
# 96.55349135169763
# 96.75848814862267
# 96.96348494554773
# 97.16848174247278
# 97.37347853939782
# 97.57847533632287
# 97.78347213324791
# 97.98846893017297
# 98.19346572709802
# 98.39846252402307
# 98.6034593209481
# 98.80845611787315
# 99.01345291479821
# 99.21844971172325
# 99.42344650864831
# 99.62844330557336
# 99.8334401024984
# 100.03843689942344

# %%
test_files = glob.glob("../dataset/test/*.jpg")

# %%
test_files
# Out:
# ['../dataset/test/35b287bc.jpg',
#  '../dataset/test/ee6fd7fc.jpg',
#  '../dataset/test/021f07cc.jpg',
#  '../dataset/test/004cd940.jpg',
#  '../dataset/test/3cd6fa25.jpg',
#  '../dataset/test/c6de08c5.jpg',
#  '../dataset/test/9b01c4fe.jpg',
#  '../dataset/test/621f8214.jpg',
#  '../dataset/test/8ebbfbf1.jpg',
#  '../dataset/test/72d642bc.jpg',
#  '../dataset/test/46a4eb91.jpg',
#  '../dataset/test/e4c171fd.jpg',
#  '../dataset/test/8dd05ac5.jpg',
#  '../dataset/test/35722e83.jpg',
#  '../dataset/test/36d702e1.jpg',
#  '../dataset/test/930dbbc0.jpg',
#  '../dataset/test/591b94a6.jpg',
#  '../dataset/test/595d5004.jpg',
#  '../dataset/test/42ae2342.jpg',
#  '../dataset/test/cb90195c.jpg',
#  '../dataset/test/fb8fed78.jpg',
#  '../dataset/test/0be3c882.jpg',
#  '../dataset/test/aee68659.jpg',
#  '../dataset/test/dba9aa05.jpg',
#  '../dataset/test/ac1f9783.jpg',
#  '../dataset/test/b390317d.jpg',
#  '../dataset/test/6c299356.jpg',
#  '../dataset/test/e40b104f.jpg',
#  '../dataset/test/2eeba64d.jpg',
#  '../dataset/test/b73c3b0a.jpg',
#  '../dataset/test/371fc10d.jpg',
#  '../dataset/test/73a6791b.jpg',
#  '../dataset/test/3f7a7e22.jpg',
#  '../dataset/test/1083ec95.jpg',
#  '../dataset/test/7f51b446.jpg',
#  '../dataset/test/d96c23a1.jpg',
#  '../dataset/test/9ad9d48f.jpg',
#  '../dataset/test/a0dbf223.jpg',
#  '../dataset/test/95ac04df.jpg',
#  '../dataset/test/cdcbdb1c.jpg',
#  '../dataset/test/f32ad244.jpg',
#  '../dataset/test/650628ef.jpg',
#  '../dataset/test/625b5346.jpg',
#  '../dataset/test/1fd3ec33.jpg',
#  '../dataset/test/b61cd7ca.jpg',
#  '../dataset/test/47e92dd5.jpg',
#  '../dataset/test/ed645978.jpg',
#  '../dataset/test/47831f19.jpg',
#  '../dataset/test/2afcdac0.jpg',
#  '../dataset/test/4857dc0a.jpg',
#  '../dataset/test/a34f4aba.jpg',
#  '../dataset/test/58c36f24.jpg',
#  '../dataset/test/2e356b16.jpg',
#  '../dataset/test/02a30984.jpg',
#  '../dataset/test/99425d0c.jpg',
#  '../dataset/test/0ba30afe.jpg',
#  '../dataset/test/8aa11310.jpg',
#  '../dataset/test/613967d7.jpg',
#  '../dataset/test/6155ece7.jpg',
#  '../dataset/test/935d82ba.jpg',
#  '../dataset/test/43771df5.jpg',
#  '../dataset/test/92faa8d4.jpg',
#  '../dataset/test/ce7f0f40.jpg',
#  '../dataset/test/29333d9f.jpg',
#  '../dataset/test/85cedfbe.jpg',
#  '../dataset/test/395b47a3.jpg',
#  '../dataset/test/908e7fb1.jpg',
#  '../dataset/test/c156e5e2.jpg',
#  '../dataset/test/2ff6aa2f.jpg',
#  '../dataset/test/3e882e34.jpg',
#  '../dataset/test/01adb909.jpg',
#  '../dataset/test/f1be272a.jpg',
#  '../dataset/test/07e34d1c.jpg',
#  '../dataset/test/a38151be.jpg',
#  '../dataset/test/7b58ce33.jpg',
#  '../dataset/test/645cb431.jpg',
#  '../dataset/test/fb56c75c.jpg',
#  '../dataset/test/b84e6f63.jpg',
#  '../dataset/test/bdc8f8c0.jpg',
#  '../dataset/test/5f2b3561.jpg',
#  '../dataset/test/22a03048.jpg',
#  '../dataset/test/689ecfc6.jpg',
#  '../dataset/test/5066368c.jpg',
#  '../dataset/test/39bcf83b.jpg',
#  '../dataset/test/9859d14f.jpg',
#  '../dataset/test/165880b0.jpg',
#  '../dataset/test/1d0ede23.jpg',
#  '../dataset/test/8f8d5dc0.jpg',
#  '../dataset/test/be261ab0.jpg',
#  '../dataset/test/12b6600c.jpg',
#  '../dataset/test/c10ac906.jpg',
#  '../dataset/test/34dc7434.jpg',
#  '../dataset/test/eeedaf09.jpg',
#  '../dataset/test/a8274765.jpg',
#  '../dataset/test/1fdc74d6.jpg',
#  '../dataset/test/ce08b86d.jpg',
#  '../dataset/test/09398c4c.jpg',
#  '../dataset/test/44a38da7.jpg',
#  '../dataset/test/46768514.jpg',
#  '../dataset/test/838731d9.jpg',
#  '../dataset/test/16e3c8ff.jpg',
#  '../dataset/test/cb8568d6.jpg',
#  '../dataset/test/c35e131a.jpg',
#  '../dataset/test/51d4eeb8.jpg',
#  '../dataset/test/4f48b943.jpg',
#  '../dataset/test/ebc858c0.jpg',
#  '../dataset/test/0fb5e075.jpg',
#  '../dataset/test/9f5e95f8.jpg',
#  '../dataset/test/4e0308db.jpg',
#  '../dataset/test/2abac975.jpg',
#  '../dataset/test/1a5c72d4.jpg',
#  '../dataset/test/c453a21b.jpg',
#  '../dataset/test/5d358874.jpg',
#  '../dataset/test/c92c93c7.jpg',
#  '../dataset/test/265f5c72.jpg',
#  '../dataset/test/f51756c7.jpg',
#  '../dataset/test/b5e666c6.jpg',
#  '../dataset/test/10cb31da.jpg',
#  '../dataset/test/336c5c85.jpg',
#  '../dataset/test/13e38ab5.jpg',
#  '../dataset/test/0df04b63.jpg',
#  '../dataset/test/6b510466.jpg',
#  '../dataset/test/3807b8a0.jpg',
#  '../dataset/test/0858b313.jpg',
#  '../dataset/test/1a238641.jpg',
#  '../dataset/test/79e740c4.jpg',
#  '../dataset/test/bca07116.jpg',
#  '../dataset/test/4aacebfb.jpg',
#  '../dataset/test/2b401dea.jpg',
#  '../dataset/test/a3def700.jpg',
#  '../dataset/test/b13dced4.jpg',
#  '../dataset/test/473291a3.jpg',
#  '../dataset/test/54776c7a.jpg',
#  '../dataset/test/41c404a4.jpg',
#  '../dataset/test/d8ac7170.jpg',
#  '../dataset/test/90452183.jpg',
#  '../dataset/test/e6428ba4.jpg',
#  '../dataset/test/956de365.jpg',
#  '../dataset/test/6c106890.jpg',
#  '../dataset/test/be9b7cbb.jpg',
#  '../dataset/test/3fc39141.jpg',
#  '../dataset/test/d297a4ef.jpg',
#  '../dataset/test/de602042.jpg',
#  '../dataset/test/d7aecccb.jpg',
#  '../dataset/test/59233bfb.jpg',
#  '../dataset/test/765ce5cc.jpg',
#  '../dataset/test/69c6808b.jpg',
#  '../dataset/test/c66ec8e2.jpg',
#  '../dataset/test/c0f7174f.jpg',
#  '../dataset/test/ae7179c7.jpg',
#  '../dataset/test/9a2b1cfb.jpg',
#  '../dataset/test/a993e8e6.jpg',
#  '../dataset/test/d9ab6236.jpg',
#  '../dataset/test/4a2e6690.jpg',
#  '../dataset/test/6407a44c.jpg',
#  '../dataset/test/14cac1a0.jpg',
#  '../dataset/test/66796869.jpg',
#  '../dataset/test/2d62abcb.jpg',
#  '../dataset/test/8859e681.jpg',
#  '../dataset/test/1ae3872a.jpg',
#  '../dataset/test/92c2f1c0.jpg',
#  '../dataset/test/91d68b43.jpg',
#  '../dataset/test/0056000b.jpg',
#  '../dataset/test/2d11b0dd.jpg',
#  '../dataset/test/84af8c30.jpg',
#  '../dataset/test/b33a47cc.jpg',
#  '../dataset/test/788a08b0.jpg',
#  '../dataset/test/d7e142a3.jpg',
#  '../dataset/test/5d0e0043.jpg',
#  '../dataset/test/9a867c9e.jpg',
#  '../dataset/test/4cd7407e.jpg',
#  '../dataset/test/86c71589.jpg',
#  '../dataset/test/9bab2705.jpg',
#  '../dataset/test/be02cda4.jpg',
#  '../dataset/test/5471fe31.jpg',
#  '../dataset/test/5590f7ec.jpg',
#  '../dataset/test/e9dd7dfa.jpg',
#  '../dataset/test/be4e4a66.jpg',
#  '../dataset/test/aeeb3faf.jpg',
#  '../dataset/test/38a2a5c3.jpg',
#  '../dataset/test/6004207b.jpg',
#  '../dataset/test/13f44c41.jpg',
#  '../dataset/test/66830611.jpg',
#  '../dataset/test/f1db6d31.jpg',
#  '../dataset/test/20cee99f.jpg',
#  '../dataset/test/f2318c66.jpg',
#  '../dataset/test/09e51993.jpg',
#  '../dataset/test/1c30a17d.jpg',
#  '../dataset/test/4f0175ba.jpg',
#  '../dataset/test/243b060b.jpg',
#  '../dataset/test/91c3ffd3.jpg',
#  '../dataset/test/bfb2636b.jpg',
#  '../dataset/test/32431f4d.jpg',
#  '../dataset/test/54385bc2.jpg',
#  '../dataset/test/d6575239.jpg',
#  '../dataset/test/4a1c3d91.jpg',
#  '../dataset/test/3a519ffa.jpg',
#  '../dataset/test/d0da3c12.jpg',
#  '../dataset/test/3af14797.jpg',
#  '../dataset/test/2d169feb.jpg',
#  '../dataset/test/a26fad4d.jpg',
#  '../dataset/test/c979826e.jpg',
#  '../dataset/test/6cb9e39b.jpg',
#  '../dataset/test/aa92e238.jpg',
#  '../dataset/test/eee8af8e.jpg',
#  '../dataset/test/890685ff.jpg',
#  '../dataset/test/96c46a9f.jpg',
#  '../dataset/test/7434d8c5.jpg',
#  '../dataset/test/bece170b.jpg',
#  '../dataset/test/f9dd2ba1.jpg',
#  '../dataset/test/a8830473.jpg',
#  '../dataset/test/6aab7ad6.jpg',
#  '../dataset/test/0ab5c2da.jpg',
#  '../dataset/test/e77f316a.jpg',
#  '../dataset/test/eb9aa389.jpg',
#  '../dataset/test/a75469aa.jpg',
#  '../dataset/test/a59431af.jpg',
#  '../dataset/test/fd9f87ea.jpg',
#  '../dataset/test/b71b9ea5.jpg',
#  '../dataset/test/630bd881.jpg',
#  '../dataset/test/f3ecacfe.jpg',
#  '../dataset/test/d3cf7753.jpg',
#  '../dataset/test/cbf35d13.jpg',
#  '../dataset/test/35775158.jpg',
#  '../dataset/test/14c312bc.jpg',
#  '../dataset/test/5156c1e4.jpg',
#  '../dataset/test/917b769e.jpg',
#  '../dataset/test/c4625979.jpg',
#  '../dataset/test/52649661.jpg',
#  '../dataset/test/9e38b1e7.jpg',
#  '../dataset/test/edd71b21.jpg',
#  '../dataset/test/62cc0811.jpg',
#  '../dataset/test/d203994b.jpg',
#  '../dataset/test/e40e1039.jpg',
#  '../dataset/test/78dad3d1.jpg',
#  '../dataset/test/b0607baa.jpg',
#  '../dataset/test/dc9b227f.jpg',
#  '../dataset/test/d067cc8d.jpg',
#  '../dataset/test/14e63854.jpg',
#  '../dataset/test/a1a07ee3.jpg',
#  '../dataset/test/d1863c13.jpg',
#  '../dataset/test/0647afb6.jpg',
#  '../dataset/test/b437438f.jpg',
#  '../dataset/test/6933917c.jpg',
#  '../dataset/test/ea0062be.jpg',
#  '../dataset/test/0a5b8b78.jpg',
#  '../dataset/test/02e6a238.jpg',
#  '../dataset/test/943b08ad.jpg',
#  '../dataset/test/2998e03b.jpg',
#  '../dataset/test/29a0e470.jpg',
#  '../dataset/test/df0eb942.jpg',
#  '../dataset/test/16ef8d09.jpg',
#  '../dataset/test/a0880493.jpg',
#  '../dataset/test/711fb1b5.jpg',
#  '../dataset/test/e7af742a.jpg',
#  '../dataset/test/6e4a6947.jpg',
#  '../dataset/test/b620bdc1.jpg',
#  '../dataset/test/5fdaf7ba.jpg',
#  '../dataset/test/3d933bda.jpg',
#  '../dataset/test/5a1ec291.jpg',
#  '../dataset/test/42f8fda6.jpg',
#  '../dataset/test/b558ef5b.jpg',
#  '../dataset/test/d90de498.jpg',
#  '../dataset/test/371662a8.jpg',
#  '../dataset/test/4687f0a0.jpg',
#  '../dataset/test/c22bc176.jpg',
#  '../dataset/test/d3e174e6.jpg',
#  '../dataset/test/58aa7309.jpg',
#  '../dataset/test/f151cf92.jpg',
#  '../dataset/test/d0ac21a9.jpg',
#  '../dataset/test/208b2c71.jpg',
#  '../dataset/test/4f03ea25.jpg',
#  '../dataset/test/3349e251.jpg',
#  '../dataset/test/2a2e4fe0.jpg',
#  '../dataset/test/03df3506.jpg',
#  '../dataset/test/41d3f4c3.jpg',
#  '../dataset/test/113e0b61.jpg',
#  '../dataset/test/eac1ff52.jpg',
#  '../dataset/test/ffe7a6c0.jpg',
#  '../dataset/test/d1603069.jpg',
#  '../dataset/test/0a497952.jpg',
#  '../dataset/test/16c99a01.jpg',
#  '../dataset/test/9ad550b6.jpg',
#  '../dataset/test/ff3e07d6.jpg',
#  '../dataset/test/bec10730.jpg',
#  '../dataset/test/6912e71e.jpg',
#  '../dataset/test/aa352590.jpg',
#  '../dataset/test/f85c3c55.jpg',
#  '../dataset/test/7d65cd54.jpg',
#  '../dataset/test/39a55c00.jpg',
#  '../dataset/test/97837200.jpg',
#  '../dataset/test/64f63db2.jpg',
#  '../dataset/test/dbd377d5.jpg',
#  '../dataset/test/ed7ddb31.jpg',
#  '../dataset/test/90e7c771.jpg',
#  '../dataset/test/857821d3.jpg',
#  '../dataset/test/b87c1283.jpg',
#  '../dataset/test/4eaa9298.jpg',
#  '../dataset/test/4e402309.jpg',
#  '../dataset/test/f83b8a44.jpg',
#  '../dataset/test/369046b4.jpg',
#  '../dataset/test/18ff383f.jpg',
#  '../dataset/test/be1aee67.jpg',
#  '../dataset/test/5f210864.jpg',
#  '../dataset/test/13d89cea.jpg',
#  '../dataset/test/c84c7d50.jpg',
#  '../dataset/test/2ed97cfb.jpg',
#  '../dataset/test/572af8f2.jpg',
#  '../dataset/test/17e684ff.jpg',
#  '../dataset/test/deed5a98.jpg',
#  '../dataset/test/37dd3db7.jpg',
#  '../dataset/test/30bac0d7.jpg',
#  '../dataset/test/fe69f36e.jpg',
#  '../dataset/test/81ff4af7.jpg',
#  '../dataset/test/b8ac4d1c.jpg',
#  '../dataset/test/b7386256.jpg',
#  '../dataset/test/c3a5bfd7.jpg',
#  '../dataset/test/999dbb51.jpg',
#  '../dataset/test/050cfb88.jpg',
#  '../dataset/test/4857d191.jpg',
#  '../dataset/test/fc29805a.jpg',
#  '../dataset/test/10fe7a4f.jpg',
#  '../dataset/test/90945353.jpg',
#  '../dataset/test/89d5125b.jpg',
#  '../dataset/test/0b40b82e.jpg',
#  '../dataset/test/bcd681d4.jpg',
#  '../dataset/test/02f84c93.jpg',
#  '../dataset/test/8e4b5af3.jpg',
#  '../dataset/test/e9f90502.jpg',
#  '../dataset/test/194b8479.jpg',
#  '../dataset/test/8ab9b557.jpg',
#  '../dataset/test/38037cb2.jpg',
#  '../dataset/test/b5e9354d.jpg',
#  '../dataset/test/78471e91.jpg',
#  '../dataset/test/2ae5dcf4.jpg',
#  '../dataset/test/7a16a20d.jpg',
#  '../dataset/test/f8892c9e.jpg',
#  '../dataset/test/b5894ec0.jpg',
#  '../dataset/test/8d8af3f0.jpg',
#  '../dataset/test/2e307a15.jpg',
#  '../dataset/test/80d1cd31.jpg',
#  '../dataset/test/30b76a67.jpg',
#  '../dataset/test/634a81d4.jpg',
#  '../dataset/test/c6564f7c.jpg',
#  '../dataset/test/8fc285f6.jpg',
#  '../dataset/test/a21d7f3e.jpg',
#  '../dataset/test/6413b515.jpg',
#  '../dataset/test/1d9bed94.jpg',
#  '../dataset/test/d99a62f1.jpg',
#  '../dataset/test/4aebd78d.jpg',
#  '../dataset/test/97aaeea4.jpg',
#  '../dataset/test/7cd03ca7.jpg',
#  '../dataset/test/84d1034e.jpg',
#  '../dataset/test/5009f646.jpg',
#  '../dataset/test/6b141285.jpg',
#  '../dataset/test/db1ac2ed.jpg',
#  '../dataset/test/3b1609e1.jpg',
#  '../dataset/test/581046e9.jpg',
#  '../dataset/test/e826af79.jpg',
#  '../dataset/test/234f0d51.jpg',
#  '../dataset/test/bf680d1a.jpg',
#  '../dataset/test/3cea1e0f.jpg',
#  '../dataset/test/1aebfd05.jpg',
#  '../dataset/test/160f0413.jpg',
#  '../dataset/test/4c3a19e6.jpg',
#  '../dataset/test/93bbca24.jpg',
#  '../dataset/test/db8d2ec0.jpg',
#  '../dataset/test/5de1c5c7.jpg',
#  '../dataset/test/f0b826ee.jpg',
#  '../dataset/test/31c48bd5.jpg',
#  '../dataset/test/b04cad14.jpg',
#  '../dataset/test/b72f7228.jpg',
#  '../dataset/test/a29df56d.jpg',
#  '../dataset/test/cc000b05.jpg',
#  '../dataset/test/1b851846.jpg',
#  '../dataset/test/3815eaae.jpg',
#  '../dataset/test/1bf1abe8.jpg',
#  '../dataset/test/c3ebfe7a.jpg',
#  '../dataset/test/5e2482cb.jpg',
#  '../dataset/test/fae7cfa2.jpg',
#  '../dataset/test/12095c70.jpg',
#  '../dataset/test/2014b057.jpg',
#  '../dataset/test/cc411a31.jpg',
#  '../dataset/test/294d48a0.jpg',
#  '../dataset/test/f05b3965.jpg',
#  '../dataset/test/b847f081.jpg',
#  '../dataset/test/841408a9.jpg',
#  '../dataset/test/e85bf914.jpg',
#  '../dataset/test/29a47270.jpg',
#  '../dataset/test/12c5fa34.jpg',
#  '../dataset/test/3a64db85.jpg',
#  '../dataset/test/c474c3ea.jpg',
#  '../dataset/test/e9e56dc7.jpg',
#  '../dataset/test/2112d690.jpg',
#  '../dataset/test/8f91cab2.jpg',
#  '../dataset/test/f76bbb71.jpg',
#  '../dataset/test/45526ed3.jpg',
#  '../dataset/test/6b046145.jpg',
#  '../dataset/test/8f6a92bd.jpg',
#  '../dataset/test/08a09b6c.jpg',
#  '../dataset/test/c4332de0.jpg',
#  '../dataset/test/b11ff23d.jpg',
#  '../dataset/test/e08abe4a.jpg',
#  '../dataset/test/1d97a9c0.jpg',
#  '../dataset/test/0d88e16a.jpg',
#  '../dataset/test/46567b55.jpg',
#  '../dataset/test/72ac2a7a.jpg',
#  '../dataset/test/13fc016d.jpg',
#  '../dataset/test/f15bb6c1.jpg',
#  '../dataset/test/c467a1d3.jpg',
#  '../dataset/test/f6dd4850.jpg',
#  '../dataset/test/73e39c78.jpg',
#  '../dataset/test/33e86566.jpg',
#  '../dataset/test/8f0c996b.jpg',
#  '../dataset/test/560bb2e7.jpg',
#  '../dataset/test/f06b885e.jpg',
#  '../dataset/test/34cd7ded.jpg',
#  '../dataset/test/0dfeda35.jpg',
#  '../dataset/test/c9c040e9.jpg',
#  '../dataset/test/fa03be5d.jpg',
#  '../dataset/test/79943bb6.jpg',
#  '../dataset/test/05af4415.jpg',
#  '../dataset/test/594b7d88.jpg',
#  '../dataset/test/e4ddccbd.jpg',
#  '../dataset/test/db725f2d.jpg',
#  '../dataset/test/7b1b6e1f.jpg',
#  '../dataset/test/112ae572.jpg',
#  '../dataset/test/ae07327f.jpg',
#  '../dataset/test/f7d20855.jpg',
#  '../dataset/test/1e7821a1.jpg',
#  '../dataset/test/e2f875b3.jpg',
#  '../dataset/test/0bcbc4f5.jpg',
#  '../dataset/test/ae680187.jpg',
#  '../dataset/test/25f8052a.jpg',
#  '../dataset/test/2f7a84a1.jpg',
#  '../dataset/test/3e89ea79.jpg',
#  '../dataset/test/5d097b31.jpg',
#  '../dataset/test/297afac3.jpg',
#  '../dataset/test/b5983cfb.jpg',
#  '../dataset/test/9bd67216.jpg',
#  '../dataset/test/95e18b14.jpg',
#  '../dataset/test/2687ee97.jpg',
#  '../dataset/test/3dde422c.jpg',
#  '../dataset/test/a55be915.jpg',
#  '../dataset/test/7e57e457.jpg',
#  '../dataset/test/2d6e85e7.jpg',
#  '../dataset/test/0567973e.jpg',
#  '../dataset/test/e1841979.jpg',
#  '../dataset/test/b668342c.jpg',
#  '../dataset/test/c7241b5e.jpg',
#  '../dataset/test/2ca4931a.jpg',
#  '../dataset/test/fc5ffcf7.jpg',
#  '../dataset/test/e38c3de9.jpg',
#  '../dataset/test/78fa33a1.jpg',
#  '../dataset/test/66e2c3fd.jpg',
#  '../dataset/test/8e15164c.jpg',
#  '../dataset/test/fb0bf543.jpg',
#  '../dataset/test/c4dd54c9.jpg',
#  '../dataset/test/9d60031b.jpg',
#  '../dataset/test/65c7bb93.jpg',
#  '../dataset/test/2c916b3e.jpg',
#  '../dataset/test/4fb5bfad.jpg',
#  '../dataset/test/020d17d0.jpg',
#  '../dataset/test/ff3a04a8.jpg',
#  '../dataset/test/c252320e.jpg',
#  '../dataset/test/8aedb9e4.jpg',
#  '../dataset/test/3c4ca756.jpg',
#  '../dataset/test/76e60f5a.jpg',
#  '../dataset/test/69a06ac4.jpg',
#  '../dataset/test/f98dff39.jpg',
#  '../dataset/test/6ae51bca.jpg',
#  '../dataset/test/643eeed1.jpg',
#  '../dataset/test/72defc1a.jpg',
#  '../dataset/test/82d15fe1.jpg',
#  '../dataset/test/ffc6f731.jpg',
#  '../dataset/test/c2ea223b.jpg',
#  '../dataset/test/8207feb8.jpg',
#  '../dataset/test/bb4bd615.jpg',
#  '../dataset/test/a20b8804.jpg',
#  '../dataset/test/6f48d050.jpg',
#  '../dataset/test/15f5e1c4.jpg',
#  '../dataset/test/da5fbbaa.jpg',
#  '../dataset/test/30b654a2.jpg',
#  '../dataset/test/274dba78.jpg',
#  '../dataset/test/47bb2249.jpg',
#  '../dataset/test/efcb86f6.jpg',
#  '../dataset/test/91a9a7f5.jpg',
#  '../dataset/test/727f807b.jpg',
#  '../dataset/test/17463c74.jpg',
#  '../dataset/test/63f4fab9.jpg',
#  '../dataset/test/5c203982.jpg',
#  '../dataset/test/8b9be5fa.jpg',
#  '../dataset/test/802f22ee.jpg',
#  '../dataset/test/b046bb8a.jpg',
#  '../dataset/test/4ca0b3a1.jpg',
#  '../dataset/test/d4709d30.jpg',
#  '../dataset/test/aee09049.jpg',
#  '../dataset/test/98e43c64.jpg',
#  '../dataset/test/f8e2f4bc.jpg',
#  '../dataset/test/24d2f0f2.jpg',
#  '../dataset/test/d6e95719.jpg',
#  '../dataset/test/4f9b559a.jpg',
#  '../dataset/test/b9e421f3.jpg',
#  '../dataset/test/ff65a4e7.jpg',
#  '../dataset/test/65f6b91e.jpg',
#  '../dataset/test/deea8c19.jpg',
#  '../dataset/test/ed512a73.jpg',
#  '../dataset/test/1546f890.jpg',
#  '../dataset/test/0a5230c2.jpg',
#  '../dataset/test/e7fb4b5a.jpg',
#  '../dataset/test/b59aa327.jpg',
#  '../dataset/test/6e1b5a76.jpg',
#  '../dataset/test/7486b4fb.jpg',
#  '../dataset/test/5b60dea2.jpg',
#  '../dataset/test/c0a06c27.jpg',
#  '../dataset/test/5ae9cf62.jpg',
#  '../dataset/test/ddc2b22a.jpg',
#  '../dataset/test/b0312a2c.jpg',
#  '../dataset/test/9973925c.jpg',
#  '../dataset/test/f942675f.jpg',
#  '../dataset/test/2f11fcdb.jpg',
#  '../dataset/test/a190d9ca.jpg',
#  '../dataset/test/cc6cadc2.jpg',
#  '../dataset/test/d85f19da.jpg',
#  '../dataset/test/8d8571f5.jpg',
#  '../dataset/test/7ab295e8.jpg',
#  '../dataset/test/d974ca79.jpg',
#  '../dataset/test/26e65c2d.jpg',
#  '../dataset/test/f3eb3a1b.jpg',
#  '../dataset/test/3f1e5e8a.jpg',
#  '../dataset/test/54b4bbdb.jpg',
#  '../dataset/test/d2ed0d55.jpg',
#  '../dataset/test/ce9b0cda.jpg',
#  '../dataset/test/c374c832.jpg',
#  '../dataset/test/47cb6990.jpg',
#  '../dataset/test/e23cb39e.jpg',
#  '../dataset/test/5c42c5f3.jpg',
#  '../dataset/test/bacb94cc.jpg',
#  '../dataset/test/011fc871.jpg',
#  '../dataset/test/91692fe0.jpg',
#  '../dataset/test/d4b1acdf.jpg',
#  '../dataset/test/b18feb93.jpg',
#  '../dataset/test/67c43c0a.jpg',
#  '../dataset/test/1d3c2335.jpg',
#  '../dataset/test/7848b6e7.jpg',
#  '../dataset/test/5038b8b2.jpg',
#  '../dataset/test/98da4be2.jpg',
#  '../dataset/test/d8de25e2.jpg',
#  '../dataset/test/dde3d26a.jpg',
#  '../dataset/test/bead0b7e.jpg',
#  '../dataset/test/35028c7f.jpg',
#  '../dataset/test/c148b89f.jpg',
#  '../dataset/test/9a8d4005.jpg',
#  '../dataset/test/0cbcb49d.jpg',
#  '../dataset/test/4f2c9ca7.jpg',
#  '../dataset/test/0f4f22c2.jpg',
#  '../dataset/test/dcc3557a.jpg',
#  '../dataset/test/ce4ad6ea.jpg',
#  '../dataset/test/47bc5a0d.jpg',
#  '../dataset/test/03292c72.jpg',
#  '../dataset/test/2bca6341.jpg',
#  '../dataset/test/d58ebb10.jpg',
#  '../dataset/test/0c0d376e.jpg',
#  '../dataset/test/a9c167ff.jpg',
#  '../dataset/test/9e38fbf1.jpg',
#  '../dataset/test/eba60f18.jpg',
#  '../dataset/test/a7106c29.jpg',
#  '../dataset/test/2ef9ef59.jpg',
#  '../dataset/test/513c4d6b.jpg',
#  '../dataset/test/afbe35e6.jpg',
#  '../dataset/test/6d977586.jpg',
#  '../dataset/test/693f1f60.jpg',
#  '../dataset/test/6d69393e.jpg',
#  '../dataset/test/0374a0a2.jpg',
#  '../dataset/test/43a7d0ee.jpg',
#  '../dataset/test/588e3067.jpg',
#  '../dataset/test/0cbf4f8a.jpg',
#  '../dataset/test/472e6da9.jpg',
#  '../dataset/test/c8c5248d.jpg',
#  '../dataset/test/f876ca8b.jpg',
#  '../dataset/test/2e6735bf.jpg',
#  '../dataset/test/7f214eac.jpg',
#  '../dataset/test/9d1a00ed.jpg',
#  '../dataset/test/1f261407.jpg',
#  '../dataset/test/838f7643.jpg',
#  '../dataset/test/7f78a5b1.jpg',
#  '../dataset/test/039208f5.jpg',
#  '../dataset/test/d2346ce7.jpg',
#  '../dataset/test/d0f3d444.jpg',
#  '../dataset/test/4b14b1c0.jpg',
#  '../dataset/test/371b1e06.jpg',
#  '../dataset/test/3c75d621.jpg',
#  '../dataset/test/fae323b8.jpg',
#  '../dataset/test/976e766e.jpg',
#  '../dataset/test/afe38832.jpg',
#  '../dataset/test/4e2c02a1.jpg',
#  '../dataset/test/504f8f88.jpg',
#  '../dataset/test/5feaae60.jpg',
#  '../dataset/test/3f993cb6.jpg',
#  '../dataset/test/43ed7b5c.jpg',
#  '../dataset/test/a6a67d7b.jpg',
#  '../dataset/test/4b113374.jpg',
#  '../dataset/test/de3309db.jpg',
#  '../dataset/test/5a99bd4e.jpg',
#  '../dataset/test/0dbf50e7.jpg',
#  '../dataset/test/00b436ee.jpg',
#  '../dataset/test/93760c33.jpg',
#  '../dataset/test/55a84c29.jpg',
#  '../dataset/test/c3f5d4df.jpg',
#  '../dataset/test/15868edb.jpg',
#  '../dataset/test/47c675e8.jpg',
#  '../dataset/test/b9b87f28.jpg',
#  '../dataset/test/1d6bb8a8.jpg',
#  '../dataset/test/c3f09687.jpg',
#  '../dataset/test/5fbf804e.jpg',
#  '../dataset/test/53c78016.jpg',
#  '../dataset/test/e2a6b322.jpg',
#  '../dataset/test/82b07645.jpg',
#  '../dataset/test/0850b65a.jpg',
#  '../dataset/test/8b579645.jpg',
#  '../dataset/test/3a3d5f88.jpg',
#  '../dataset/test/ff738a52.jpg',
#  '../dataset/test/1135131b.jpg',
#  '../dataset/test/fee43dc1.jpg',
#  '../dataset/test/e53f05ea.jpg',
#  '../dataset/test/2d14146f.jpg',
#  '../dataset/test/e7b7d1c7.jpg',
#  '../dataset/test/2285e76f.jpg',
#  '../dataset/test/93573825.jpg',
#  '../dataset/test/2591a121.jpg',
#  '../dataset/test/57db6e32.jpg',
#  '../dataset/test/c4865fc8.jpg',
#  '../dataset/test/9ad5fe52.jpg',
#  '../dataset/test/6d0cbd99.jpg',
#  '../dataset/test/fc881d58.jpg',
#  '../dataset/test/ef0c81ac.jpg',
#  '../dataset/test/0a2b7ea9.jpg',
#  '../dataset/test/0ad105b9.jpg',
#  '../dataset/test/0edad302.jpg',
#  '../dataset/test/63abb5b2.jpg',
#  '../dataset/test/40c3a13f.jpg',
#  '../dataset/test/69d796f5.jpg',
#  '../dataset/test/cb87dd81.jpg',
#  '../dataset/test/48dfca23.jpg',
#  '../dataset/test/2e62d49b.jpg',
#  '../dataset/test/af45eca5.jpg',
#  '../dataset/test/14795325.jpg',
#  '../dataset/test/3928988c.jpg',
#  '../dataset/test/54a3af32.jpg',
#  '../dataset/test/1532d70d.jpg',
#  '../dataset/test/e17288fb.jpg',
#  '../dataset/test/5fa14013.jpg',
#  '../dataset/test/a4ba9817.jpg',
#  '../dataset/test/a1ae5cb5.jpg',
#  '../dataset/test/3be626ef.jpg',
#  '../dataset/test/3ad46aec.jpg',
#  '../dataset/test/8025072c.jpg',
#  '../dataset/test/70da92fc.jpg',
#  '../dataset/test/20c07e4b.jpg',
#  '../dataset/test/e54c498b.jpg',
#  '../dataset/test/de44b7b8.jpg',
#  '../dataset/test/e3dc2020.jpg',
#  '../dataset/test/cf341a44.jpg',
#  '../dataset/test/7f3ed146.jpg',
#  '../dataset/test/5dd573f0.jpg',
#  '../dataset/test/c51a443c.jpg',
#  '../dataset/test/e988f465.jpg',
#  '../dataset/test/2c24a732.jpg',
#  '../dataset/test/7044d0c6.jpg',
#  '../dataset/test/408ecac5.jpg',
#  '../dataset/test/1b29ff0d.jpg',
#  '../dataset/test/7ec2c595.jpg',
#  '../dataset/test/9a41819b.jpg',
#  '../dataset/test/d471c57e.jpg',
#  '../dataset/test/5602ff2f.jpg',
#  '../dataset/test/e815d139.jpg',
#  '../dataset/test/b1f76e67.jpg',
#  '../dataset/test/850dcee4.jpg',
#  '../dataset/test/b6df2ec1.jpg',
#  '../dataset/test/0fe297c2.jpg',
#  '../dataset/test/69e263b4.jpg',
#  '../dataset/test/8a13780e.jpg',
#  '../dataset/test/bb03e6fc.jpg',
#  '../dataset/test/849bd880.jpg',
#  '../dataset/test/3bb7c687.jpg',
#  '../dataset/test/6eda986c.jpg',
#  '../dataset/test/7ded76ac.jpg',
#  '../dataset/test/57a5110f.jpg',
#  '../dataset/test/24b98331.jpg',
#  '../dataset/test/e3e6c901.jpg',
#  '../dataset/test/02931ea9.jpg',
#  '../dataset/test/30055835.jpg',
#  '../dataset/test/31567fb0.jpg',
#  '../dataset/test/0dcfb467.jpg',
#  '../dataset/test/18aaa78c.jpg',
#  '../dataset/test/d652720c.jpg',
#  '../dataset/test/5c8b5026.jpg',
#  '../dataset/test/1474a2d3.jpg',
#  '../dataset/test/121a3fd8.jpg',
#  '../dataset/test/601835cc.jpg',
#  '../dataset/test/8d09b9a6.jpg',
#  '../dataset/test/2fd2a4ae.jpg',
#  '../dataset/test/99a952be.jpg',
#  '../dataset/test/966dc6bb.jpg',
#  '../dataset/test/c4cbad87.jpg',
#  '../dataset/test/7fa99f8d.jpg',
#  '../dataset/test/61669569.jpg',
#  '../dataset/test/ac9c7d44.jpg',
#  '../dataset/test/c06d7410.jpg',
#  '../dataset/test/dfe0f6d5.jpg',
#  '../dataset/test/40dee206.jpg',
#  '../dataset/test/4c434066.jpg',
#  '../dataset/test/2f0f7ea3.jpg',
#  '../dataset/test/fcc7d92d.jpg',
#  '../dataset/test/ffce2c5d.jpg',
#  '../dataset/test/434dcad3.jpg',
#  '../dataset/test/4b8fe2c0.jpg',
#  '../dataset/test/2a602adc.jpg',
#  '../dataset/test/7e762a6f.jpg',
#  '../dataset/test/96b4d5f4.jpg',
#  '../dataset/test/048512e2.jpg',
#  '../dataset/test/e1ad9104.jpg',
#  '../dataset/test/d74aa0e5.jpg',
#  '../dataset/test/ab9146be.jpg',
#  '../dataset/test/2b50c819.jpg',
#  '../dataset/test/0ad31362.jpg',
#  '../dataset/test/eee76430.jpg',
#  '../dataset/test/210239be.jpg',
#  '../dataset/test/0e90fb0c.jpg',
#  '../dataset/test/d30c608d.jpg',
#  '../dataset/test/60f5ddc0.jpg',
#  '../dataset/test/97dd51fe.jpg',
#  '../dataset/test/4f442447.jpg',
#  '../dataset/test/41aef483.jpg',
#  '../dataset/test/486f6880.jpg',
#  '../dataset/test/73822c42.jpg',
#  '../dataset/test/49ef61c3.jpg',
#  '../dataset/test/bfbd5104.jpg',
#  '../dataset/test/8e0f5e74.jpg',
#  '../dataset/test/b3c43ff7.jpg',
#  '../dataset/test/b4f03d12.jpg',
#  '../dataset/test/d6a1e954.jpg',
#  '../dataset/test/1ec2dab9.jpg',
#  '../dataset/test/2f71b811.jpg',
#  '../dataset/test/955e0f92.jpg',
#  '../dataset/test/06b0cf32.jpg',
#  '../dataset/test/a7d607c6.jpg',
#  '../dataset/test/1cb5548c.jpg',
#  '../dataset/test/d7a98fb3.jpg',
#  '../dataset/test/fb026a98.jpg',
#  '../dataset/test/8b56cfca.jpg',
#  '../dataset/test/e5df15c3.jpg',
#  '../dataset/test/87bf4ffd.jpg',
#  '../dataset/test/6cd62faf.jpg',
#  '../dataset/test/20e3ad2f.jpg',
#  '../dataset/test/4b369237.jpg',
#  '../dataset/test/89dc8ac9.jpg',
#  '../dataset/test/df4e8e26.jpg',
#  '../dataset/test/bedaf16a.jpg',
#  '../dataset/test/753279de.jpg',
#  '../dataset/test/c0ca867d.jpg',
#  '../dataset/test/140dce2d.jpg',
#  '../dataset/test/4b35b25d.jpg',
#  '../dataset/test/6855f6a9.jpg',
#  '../dataset/test/9d815119.jpg',
#  '../dataset/test/fec8698f.jpg',
#  '../dataset/test/c8b7ba4d.jpg',
#  '../dataset/test/afc131f7.jpg',
#  '../dataset/test/47aa9bf3.jpg',
#  '../dataset/test/78da3ecc.jpg',
#  '../dataset/test/4aab661b.jpg',
#  '../dataset/test/fe3b752c.jpg',
#  '../dataset/test/048e1daa.jpg',
#  '../dataset/test/270b5d29.jpg',
#  '../dataset/test/09845507.jpg',
#  '../dataset/test/5f565348.jpg',
#  '../dataset/test/c0317da9.jpg',
#  '../dataset/test/1de564f6.jpg',
#  '../dataset/test/cb59124c.jpg',
#  '../dataset/test/a6b0ffa0.jpg',
#  '../dataset/test/3821a075.jpg',
#  '../dataset/test/e57d01a5.jpg',
#  '../dataset/test/03119ded.jpg',
#  '../dataset/test/c1b4a98c.jpg',
#  '../dataset/test/bb2b7703.jpg',
#  '../dataset/test/714d3459.jpg',
#  '../dataset/test/3f97dcdf.jpg',
#  '../dataset/test/bc29c5d3.jpg',
#  '../dataset/test/4d67a6c0.jpg',
#  '../dataset/test/d900c6fc.jpg',
#  '../dataset/test/42c50637.jpg',
#  '../dataset/test/50f3f7ab.jpg',
#  '../dataset/test/396eec6a.jpg',
#  '../dataset/test/3645edc8.jpg',
#  '../dataset/test/03b17658.jpg',
#  '../dataset/test/09355112.jpg',
#  '../dataset/test/be5fa26b.jpg',
#  '../dataset/test/199dd40a.jpg',
#  '../dataset/test/67dbfc98.jpg',
#  '../dataset/test/a26c504c.jpg',
#  '../dataset/test/b8e61303.jpg',
#  '../dataset/test/209f2a9e.jpg',
#  '../dataset/test/434dfd1a.jpg',
#  '../dataset/test/c75bffd8.jpg',
#  '../dataset/test/50d31c49.jpg',
#  '../dataset/test/2905a48a.jpg',
#  '../dataset/test/a37e4182.jpg',
#  '../dataset/test/f36e75ee.jpg',
#  '../dataset/test/e86dbf2d.jpg',
#  '../dataset/test/da6a57b5.jpg',
#  '../dataset/test/80d88a24.jpg',
#  '../dataset/test/2b4ea4fb.jpg',
#  '../dataset/test/39d565bc.jpg',
#  '../dataset/test/0ac3e80f.jpg',
#  '../dataset/test/a708f869.jpg',
#  '../dataset/test/53a9fed8.jpg',
#  '../dataset/test/b0a6eba6.jpg',
#  '../dataset/test/a98bfd97.jpg',
#  '../dataset/test/f2dd0398.jpg',
#  '../dataset/test/dbf3d520.jpg',
#  '../dataset/test/358fa74f.jpg',
#  '../dataset/test/e4840666.jpg',
#  '../dataset/test/9159eda5.jpg',
#  '../dataset/test/85b19c77.jpg',
#  '../dataset/test/725cba00.jpg',
#  '../dataset/test/dadb12cb.jpg',
#  '../dataset/test/5aaa7b7d.jpg',
#  '../dataset/test/fec35fb2.jpg',
#  '../dataset/test/d365c136.jpg',
#  '../dataset/test/84ac83d7.jpg',
#  '../dataset/test/18bf1f7b.jpg',
#  '../dataset/test/d5833a89.jpg',
#  '../dataset/test/a693b34f.jpg',
#  '../dataset/test/2a1838da.jpg',
#  '../dataset/test/9e483373.jpg',
#  '../dataset/test/31722bf6.jpg',
#  '../dataset/test/44ba611f.jpg',
#  '../dataset/test/39e328e5.jpg',
#  '../dataset/test/55837719.jpg',
#  '../dataset/test/7e1f2820.jpg',
#  '../dataset/test/848631ff.jpg',
#  '../dataset/test/0db6eca7.jpg',
#  '../dataset/test/0674ed18.jpg',
#  '../dataset/test/04d1b1e2.jpg',
#  '../dataset/test/df89eeb3.jpg',
#  '../dataset/test/0e899cd7.jpg',
#  '../dataset/test/cd474bfc.jpg',
#  '../dataset/test/5a355191.jpg',
#  '../dataset/test/81b31ad7.jpg',
#  '../dataset/test/e74729e4.jpg',
#  '../dataset/test/ca6851af.jpg',
#  '../dataset/test/406e3c5c.jpg',
#  '../dataset/test/e6d9cc0a.jpg',
#  '../dataset/test/a4e22701.jpg',
#  '../dataset/test/a8e334e1.jpg',
#  '../dataset/test/0382090e.jpg',
#  '../dataset/test/a6a83418.jpg',
#  '../dataset/test/54dd2697.jpg',
#  '../dataset/test/ef8ab998.jpg',
#  '../dataset/test/7d0ad94b.jpg',
#  '../dataset/test/dbe7cce5.jpg',
#  '../dataset/test/2917d68c.jpg',
#  '../dataset/test/3d49bad6.jpg',
#  '../dataset/test/6913bd4d.jpg',
#  '../dataset/test/bd388ee0.jpg',
#  '../dataset/test/9206e079.jpg',
#  '../dataset/test/836bd168.jpg',
#  '../dataset/test/115d307a.jpg',
#  '../dataset/test/32b9ab7c.jpg',
#  '../dataset/test/813a40bb.jpg',
#  '../dataset/test/20789779.jpg',
#  '../dataset/test/170b1d2f.jpg',
#  '../dataset/test/47009998.jpg',
#  '../dataset/test/edc38c09.jpg',
#  '../dataset/test/d81cd8c5.jpg',
#  '../dataset/test/b755af68.jpg',
#  '../dataset/test/9d86813d.jpg',
#  '../dataset/test/b4f5e498.jpg',
#  '../dataset/test/e539fb72.jpg',
#  '../dataset/test/c9671f3f.jpg',
#  '../dataset/test/cb6f7a9c.jpg',
#  '../dataset/test/586102b2.jpg',
#  '../dataset/test/ecafe233.jpg',
#  '../dataset/test/bca8d5d4.jpg',
#  '../dataset/test/ed278f82.jpg',
#  '../dataset/test/25d162d5.jpg',
#  '../dataset/test/c6c443c4.jpg',
#  '../dataset/test/4bc057df.jpg',
#  '../dataset/test/ac650322.jpg',
#  '../dataset/test/67c59d32.jpg',
#  '../dataset/test/6596e104.jpg',
#  '../dataset/test/a7b5dc4f.jpg',
#  '../dataset/test/45e9da9e.jpg',
#  '../dataset/test/0456f788.jpg',
#  '../dataset/test/1baa2256.jpg',
#  '../dataset/test/f1414445.jpg',
#  '../dataset/test/fbdc9a1b.jpg',
#  '../dataset/test/274a7962.jpg',
#  '../dataset/test/b85cfbeb.jpg',
#  '../dataset/test/ab4af098.jpg',
#  '../dataset/test/9fab5a94.jpg',
#  '../dataset/test/d055d77b.jpg',
#  '../dataset/test/c7b998aa.jpg',
#  '../dataset/test/8dc7d335.jpg',
#  '../dataset/test/139e00a9.jpg',
#  '../dataset/test/989c6b29.jpg',
#  '../dataset/test/c16ddc23.jpg',
#  '../dataset/test/4b554d8d.jpg',
#  '../dataset/test/c20edd61.jpg',
#  '../dataset/test/3197f239.jpg',
#  '../dataset/test/44ab3baf.jpg',
#  '../dataset/test/c59b8a0b.jpg',
#  '../dataset/test/b0cd70ff.jpg',
#  '../dataset/test/4d5d5724.jpg',
#  '../dataset/test/9f180309.jpg',
#  '../dataset/test/bdd9865b.jpg',
#  '../dataset/test/639214ac.jpg',
#  '../dataset/test/f892ab71.jpg',
#  '../dataset/test/fd841f20.jpg',
#  '../dataset/test/f3f9d3da.jpg',
#  '../dataset/test/87e9418b.jpg',
#  '../dataset/test/bb1ae392.jpg',
#  '../dataset/test/fa1502db.jpg',
#  '../dataset/test/9c700762.jpg',
#  '../dataset/test/f8991794.jpg',
#  '../dataset/test/a1f0e298.jpg',
#  '../dataset/test/3e8420ea.jpg',
#  '../dataset/test/51df4ef1.jpg',
#  '../dataset/test/366d957d.jpg',
#  '../dataset/test/e952f0b8.jpg',
#  '../dataset/test/ca9b78ae.jpg',
#  '../dataset/test/045a1f17.jpg',
#  '../dataset/test/beb2798f.jpg',
#  '../dataset/test/e512a3ef.jpg',
#  '../dataset/test/a1eec872.jpg',
#  '../dataset/test/2955089f.jpg',
#  '../dataset/test/ac078754.jpg',
#  '../dataset/test/04342c48.jpg',
#  '../dataset/test/89c3d302.jpg',
#  '../dataset/test/bfb02cdf.jpg',
#  '../dataset/test/f67796a8.jpg',
#  '../dataset/test/f492f6e0.jpg',
#  '../dataset/test/59b7fb46.jpg',
#  '../dataset/test/c05585d8.jpg',
#  '../dataset/test/6097e342.jpg',
#  '../dataset/test/4e6c8ee3.jpg',
#  '../dataset/test/827692e4.jpg',
#  '../dataset/test/144d43e7.jpg',
#  '../dataset/test/eae0150b.jpg',
#  '../dataset/test/76da3d3a.jpg',
#  '../dataset/test/8a55e8df.jpg',
#  '../dataset/test/978f3785.jpg',
#  '../dataset/test/46ec1201.jpg',
#  '../dataset/test/1c8783b6.jpg',
#  '../dataset/test/6a1bc2cb.jpg',
#  '../dataset/test/a1c561f0.jpg',
#  '../dataset/test/c2727ef1.jpg',
#  '../dataset/test/5b196cf4.jpg',
#  '../dataset/test/31af3ede.jpg',
#  '../dataset/test/495e3877.jpg',
#  '../dataset/test/859ceb0e.jpg',
#  '../dataset/test/fb56d2ba.jpg',
#  '../dataset/test/fd2ec63f.jpg',
#  '../dataset/test/fe3912d4.jpg',
#  '../dataset/test/f8ed7aa0.jpg',
#  '../dataset/test/fb4d60be.jpg',
#  '../dataset/test/793a32d7.jpg',
#  '../dataset/test/49d784a7.jpg',
#  '../dataset/test/748fe005.jpg',
#  '../dataset/test/4acd4e2a.jpg',
#  '../dataset/test/a70b4a04.jpg',
#  '../dataset/test/99321867.jpg',
#  '../dataset/test/ff211776.jpg',
#  '../dataset/test/9dc30144.jpg',
#  '../dataset/test/6bd1f794.jpg',
#  '../dataset/test/ada14748.jpg',
#  '../dataset/test/406d5259.jpg',
#  '../dataset/test/4ed01dce.jpg',
#  '../dataset/test/898ffa37.jpg',
#  '../dataset/test/890387cc.jpg',
#  '../dataset/test/bbed744c.jpg',
#  '../dataset/test/b47bf319.jpg',
#  '../dataset/test/ef0c487d.jpg',
#  '../dataset/test/e9eb5d6e.jpg',
#  '../dataset/test/54a1dd43.jpg',
#  '../dataset/test/e53fc16b.jpg',
#  '../dataset/test/7f90d10a.jpg',
#  '../dataset/test/3f4a4bc4.jpg',
#  '../dataset/test/830311a0.jpg',
#  '../dataset/test/2e2a8437.jpg',
#  '../dataset/test/43740a3a.jpg',
#  '../dataset/test/7314f3ae.jpg',
#  '../dataset/test/a00d8913.jpg',
#  '../dataset/test/2f1cf14d.jpg',
#  '../dataset/test/07c2ee47.jpg',
#  '../dataset/test/dade9a9c.jpg',
#  '../dataset/test/aedcdfc5.jpg',
#  '../dataset/test/7f18e3ae.jpg',
#  '../dataset/test/d9327922.jpg',
#  '../dataset/test/f7e05e13.jpg',
#  ...]
